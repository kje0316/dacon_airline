# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import math
import json
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from IPython.display import Image
import seaborn as sns
# import missingno as msnco

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
sample_df = pd.read_csv('sample_submission.csv')

# %%
#Cancelled와 Diverted 데이터는 모든 데이터가 0으로 존재 --> drop 
train_df.drop(['Cancelled','Diverted'], axis=1, inplace= True) 

#delay 1, 0 으로 변환
dic = {'Not_Delayed' : 0, 'Delayed' : 1}
train_df['Delay'] = train_df['Delay'].map(dic) # delay float타입으로 변경

# %%
df = train_df[['ID','Estimated_Departure_Time','Estimated_Arrival_Time','Origin_State','Destination_State','Distance','Delay']]

# %%
df = df[df['Estimated_Arrival_Time']>df['Estimated_Departure_Time']] #도착시간이 출발시간보다 큰 경우만

# %%
df.dropna(subset=['Origin_State', 'Destination_State'], inplace=True)

# %%
df.isna().sum()
# Out:
# ID                               0
# Estimated_Departure_Time         0
# Estimated_Arrival_Time           0
# Origin_State                     0
# Destination_State                0
# Distance                         0
# Delay                       453129
# dtype: int64

# %%
#시차 계산 함수. time_delay 딕셔너리에 시차 업로드
def find_time_lag(train_df, state):
    OA = train_df[train_df['Origin_State'] == state]
    predict_st = OA.Destination_State.unique().tolist()
    DA = train_df[train_df['Destination_State'] == state]
    time_delay_dict = {}
    for st in predict_st:
        st_oa = OA[OA['Destination_State'] == st]
        st_oa_diff = st_oa.Estimated_Arrival_Time.mean() - st_oa.Estimated_Departure_Time.mean()
        st_da = DA[DA['Origin_State'] == st]
        st_da_diff = st_da.Estimated_Arrival_Time.mean() - st_da.Estimated_Departure_Time.mean()
        time_delay = st_da_diff - st_oa_diff
        if not np.isnan(time_delay):
            time_delay_dict[state, st] = -round(time_delay/2/60)
    
    return time_delay_dict

time_delay = dict()
for i in train_df['Origin_State'].unique().tolist():
    time_delay.update(find_time_lag(train_df, i))
    
print(time_delay)
# Out:
# {('Oklahoma', 'Texas'): 0, ('Oklahoma', 'Colorado'): -2, ('Oklahoma', 'Georgia'): 1, ('Oklahoma', 'Illinois'): 0, ('Oklahoma', 'New Jersey'): 1, ('Oklahoma', 'California'): -3, ('Oklahoma', 'Virginia'): 1, ('Oklahoma', 'Florida'): 1, ('Oklahoma', 'Missouri'): 0, ('Oklahoma', 'Nevada'): -1, ('Oklahoma', 'North Carolina'): 2, ('Oklahoma', 'Minnesota'): 0, ('Oklahoma', 'Arizona'): -2, ('Oklahoma', 'Utah'): -2, ('Oklahoma', 'Maryland'): 1, ('Oklahoma', 'Michigan'): 1, ('Oklahoma', 'Pennsylvania'): 1, ('Oklahoma', 'Washington'): -3, ('Illinois', 'Utah'): -1, ('Illinois', 'Missouri'): 0, ('Illinois', 'Kentucky'): 0, ('Illinois', 'Tennessee'): 0, ('Illinois', 'Ohio'): 0, ('Illinois', 'Minnesota'): 0, ('Illinois', 'West Virginia'): 2, ('Illinois', 'Michigan'): 1, ('Illinois', 'Oklahoma'): 0, ('Illinois', 'Washington'): 0, ('Illinois', 'New York'): 1, ('Illinois', 'Texas'): 0, ('Illinois', 'California'): 0, ('Illinois', 'Indiana'): 1, ('Illinois', 'Illinois'): 0, ('Illinois', 'Pennsylvania'): 0, ('Illinois', 'North Carolina'): -1, ('Illinois', 'Virginia'): 1, ('Illinois', 'North Dakota'): 0, ('Illinois', 'Massachusetts'): 0, ('Illinois', 'Florida'): 1, ('Illinois', 'Nevada'): 0, ('Illinois', 'New Mexico'): -2, ('Illinois', 'South Dakota'): -1, ('Illinois', 'Maine'): 1, ('Illinois', 'Louisiana'): -1, ('Illinois', 'Georgia'): 1, ('Illinois', 'Wisconsin'): 0, ('Illinois', 'Rhode Island'): -2, ('Illinois', 'Nebraska'): 0, ('Illinois', 'Alabama'): 0, ('Illinois', 'Arkansas'): 0, ('Illinois', 'South Carolina'): -1, ('Illinois', 'Maryland'): -1, ('Illinois', 'Arizona'): -1, ('Illinois', 'Iowa'): 0, ('Illinois', 'Colorado'): -1, ('Illinois', 'Connecticut'): -2, ('Illinois', 'Idaho'): -1, ('Illinois', 'Kansas'): 0, ('Illinois', 'New Jersey'): -1, ('Illinois', 'Mississippi'): 0, ('Illinois', 'New Hampshire'): -5, ('Illinois', 'Alaska'): 15, ('Illinois', 'Vermont'): 1, ('Illinois', 'Oregon'): 1, ('Illinois', 'Montana'): -1, ('Illinois', 'Puerto Rico'): 0, ('Illinois', 'Wyoming'): -2, ('Illinois', 'Hawaii'): 13, ('Illinois', 'U.S. Virgin Islands'): 2, ('North Carolina', 'New York'): 0, ('North Carolina', 'Kentucky'): 0, ('North Carolina', 'Washington'): 0, ('North Carolina', 'North Carolina'): 0, ('North Carolina', 'Connecticut'): -2, ('North Carolina', 'Colorado'): -1, ('North Carolina', 'Arkansas'): -2, ('North Carolina', 'South Carolina'): 0, ('North Carolina', 'Maryland'): 0, ('North Carolina', 'Tennessee'): 0, ('North Carolina', 'Utah'): -3, ('North Carolina', 'Massachusetts'): -1, ('North Carolina', 'Michigan'): 0, ('North Carolina', 'New Jersey'): 0, ('North Carolina', 'Minnesota'): -2, ('North Carolina', 'Mississippi'): -2, ('North Carolina', 'Texas'): -1, ('North Carolina', 'Pennsylvania'): 0, ('North Carolina', 'Florida'): -1, ('North Carolina', 'Virginia'): 0, ('North Carolina', 'Georgia'): 0, ('North Carolina', 'Illinois'): 1, ('North Carolina', 'Alabama'): -2, ('North Carolina', 'Missouri'): -2, ('North Carolina', 'Maine'): 0, ('North Carolina', 'Ohio'): 0, ('North Carolina', 'Louisiana'): -1, ('North Carolina', 'West Virginia'): 0, ('North Carolina', 'Rhode Island'): -3, ('North Carolina', 'Iowa'): -2, ('North Carolina', 'Indiana'): -1, ('North Carolina', 'Arizona'): -2, ('North Carolina', 'California'): 2, ('North Carolina', 'New Hampshire'): -2, ('North Carolina', 'Puerto Rico'): 0, ('North Carolina', 'Nevada'): 1, ('North Carolina', 'Oklahoma'): -2, ('North Carolina', 'Wisconsin'): -2, ('North Carolina', 'Nebraska'): -1, ('North Carolina', 'Oregon'): 15, ('North Carolina', 'U.S. Virgin Islands'): 1, ('North Carolina', 'Vermont'): 0, ('North Carolina', 'South Dakota'): -4, ('California', 'New Jersey'): -1, ('California', 'California'): 0, ('California', 'Utah'): 1, ('California', 'Missouri'): 1, ('California', 'Nevada'): 0, ('California', 'Florida'): -2, ('California', 'Oregon'): -1, ('California', 'Arizona'): 0, ('California', 'Indiana'): 0, ('California', 'New Mexico'): 0, ('California', 'Hawaii'): 2, ('California', 'Texas'): 2,  ...

# %%
time_delay
# Out:
# {('Oklahoma', 'Texas'): 0,
#  ('Oklahoma', 'Colorado'): -2,
#  ('Oklahoma', 'Georgia'): 1,
#  ('Oklahoma', 'Illinois'): 0,
#  ('Oklahoma', 'New Jersey'): 1,
#  ('Oklahoma', 'California'): -3,
#  ('Oklahoma', 'Virginia'): 1,
#  ('Oklahoma', 'Florida'): 1,
#  ('Oklahoma', 'Missouri'): 0,
#  ('Oklahoma', 'Nevada'): -1,
#  ('Oklahoma', 'North Carolina'): 2,
#  ('Oklahoma', 'Minnesota'): 0,
#  ('Oklahoma', 'Arizona'): -2,
#  ('Oklahoma', 'Utah'): -2,
#  ('Oklahoma', 'Maryland'): 1,
#  ('Oklahoma', 'Michigan'): 1,
#  ('Oklahoma', 'Pennsylvania'): 1,
#  ('Oklahoma', 'Washington'): -3,
#  ('Illinois', 'Utah'): -1,
#  ('Illinois', 'Missouri'): 0,
#  ('Illinois', 'Kentucky'): 0,
#  ('Illinois', 'Tennessee'): 0,
#  ('Illinois', 'Ohio'): 0,
#  ('Illinois', 'Minnesota'): 0,
#  ('Illinois', 'West Virginia'): 2,
#  ('Illinois', 'Michigan'): 1,
#  ('Illinois', 'Oklahoma'): 0,
#  ('Illinois', 'Washington'): 0,
#  ('Illinois', 'New York'): 1,
#  ('Illinois', 'Texas'): 0,
#  ('Illinois', 'California'): 0,
#  ('Illinois', 'Indiana'): 1,
#  ('Illinois', 'Illinois'): 0,
#  ('Illinois', 'Pennsylvania'): 0,
#  ('Illinois', 'North Carolina'): -1,
#  ('Illinois', 'Virginia'): 1,
#  ('Illinois', 'North Dakota'): 0,
#  ('Illinois', 'Massachusetts'): 0,
#  ('Illinois', 'Florida'): 1,
#  ('Illinois', 'Nevada'): 0,
#  ('Illinois', 'New Mexico'): -2,
#  ('Illinois', 'South Dakota'): -1,
#  ('Illinois', 'Maine'): 1,
#  ('Illinois', 'Louisiana'): -1,
#  ('Illinois', 'Georgia'): 1,
#  ('Illinois', 'Wisconsin'): 0,
#  ('Illinois', 'Rhode Island'): -2,
#  ('Illinois', 'Nebraska'): 0,
#  ('Illinois', 'Alabama'): 0,
#  ('Illinois', 'Arkansas'): 0,
#  ('Illinois', 'South Carolina'): -1,
#  ('Illinois', 'Maryland'): -1,
#  ('Illinois', 'Arizona'): -1,
#  ('Illinois', 'Iowa'): 0,
#  ('Illinois', 'Colorado'): -1,
#  ('Illinois', 'Connecticut'): -2,
#  ('Illinois', 'Idaho'): -1,
#  ('Illinois', 'Kansas'): 0,
#  ('Illinois', 'New Jersey'): -1,
#  ('Illinois', 'Mississippi'): 0,
#  ('Illinois', 'New Hampshire'): -5,
#  ('Illinois', 'Alaska'): 15,
#  ('Illinois', 'Vermont'): 1,
#  ('Illinois', 'Oregon'): 1,
#  ('Illinois', 'Montana'): -1,
#  ('Illinois', 'Puerto Rico'): 0,
#  ('Illinois', 'Wyoming'): -2,
#  ('Illinois', 'Hawaii'): 13,
#  ('Illinois', 'U.S. Virgin Islands'): 2,
#  ('North Carolina', 'New York'): 0,
#  ('North Carolina', 'Kentucky'): 0,
#  ('North Carolina', 'Washington'): 0,
#  ('North Carolina', 'North Carolina'): 0,
#  ('North Carolina', 'Connecticut'): -2,
#  ('North Carolina', 'Colorado'): -1,
#  ('North Carolina', 'Arkansas'): -2,
#  ('North Carolina', 'South Carolina'): 0,
#  ('North Carolina', 'Maryland'): 0,
#  ('North Carolina', 'Tennessee'): 0,
#  ('North Carolina', 'Utah'): -3,
#  ('North Carolina', 'Massachusetts'): -1,
#  ('North Carolina', 'Michigan'): 0,
#  ('North Carolina', 'New Jersey'): 0,
#  ('North Carolina', 'Minnesota'): -2,
#  ('North Carolina', 'Mississippi'): -2,
#  ('North Carolina', 'Texas'): -1,
#  ('North Carolina', 'Pennsylvania'): 0,
#  ('North Carolina', 'Florida'): -1,
#  ('North Carolina', 'Virginia'): 0,
#  ('North Carolina', 'Georgia'): 0,
#  ('North Carolina', 'Illinois'): 1,
#  ('North Carolina', 'Alabama'): -2,
#  ('North Carolina', 'Missouri'): -2,
#  ('North Carolina', 'Maine'): 0,
#  ('North Carolina', 'Ohio'): 0,
#  ('North Carolina', 'Louisiana'): -1,
#  ('North Carolina', 'West Virginia'): 0,
#  ('North Carolina', 'Rhode Island'): -3,
#  ('North Carolina', 'Iowa'): -2,
#  ('North Carolina', 'Indiana'): -1,
#  ('North Carolina', 'Arizona'): -2,
#  ('North Carolina', 'California'): 2,
#  ('North Carolina', 'New Hampshire'): -2,
#  ('North Carolina', 'Puerto Rico'): 0,
#  ('North Carolina', 'Nevada'): 1,
#  ('North Carolina', 'Oklahoma'): -2,
#  ('North Carolina', 'Wisconsin'): -2,
#  ('North Carolina', 'Nebraska'): -1,
#  ('North Carolina', 'Oregon'): 15,
#  ('North Carolina', 'U.S. Virgin Islands'): 1,
#  ('North Carolina', 'Vermont'): 0,
#  ('North Carolina', 'South Dakota'): -4,
#  ('California', 'New Jersey'): -1,
#  ('California', 'California'): 0,
#  ('California', 'Utah'): 1,
#  ('California', 'Missouri'): 1,
#  ('California', 'Nevada'): 0,
#  ('California', 'Florida'): -2,
#  ('California', 'Oregon'): -1,
#  ('California', 'Arizona'): 0,
#  ('California', 'Indiana'): 0,
#  ('California', 'New Mexico'): 0,
#  ('California', 'Hawaii'): 2,
#  ('California', 'Texas'): 2,
#  ('California', 'Illinois'): 0,
#  ('California', 'New York'): -3,
#  ('California', 'Tennessee'): 0,
#  ('California', 'Washington'): 0,
#  ('California', 'Kentucky'): -3,
#  ('California', 'Colorado'): 1,
#  ('California', 'Minnesota'): 2,
#  ('California', 'Massachusetts'): -2,
#  ('California', 'Georgia'): 1,
#  ('California', 'North Carolina'): -2,
#  ('California', 'Ohio'): -5,
#  ('California', 'Alaska'): 0,
#  ('California', 'Louisiana'): 0,
#  ('California', 'Nebraska'): 3,
#  ('California', 'Pennsylvania'): -4,
#  ('California', 'Virginia'): -1,
#  ('California', 'Michigan'): -1,
#  ('California', 'Idaho'): 0,
#  ('California', 'Wyoming'): 2,
#  ('California', 'Arkansas'): 3,
#  ('California', 'Oklahoma'): 3,
#  ('California', 'Maryland'): -1,
#  ('California', 'Wisconsin'): 2,
#  ('California', 'Montana'): 1,
#  ('California', 'Connecticut'): -16,
#  ('California', 'Iowa'): 4,
#  ('California', 'Kansas'): 3,
#  ('California', 'South Dakota'): 4,
#  ('New Jersey', 'Massachusetts'): 0,
#  ('New Jersey', 'Florida'): 0,
#  ('New Jersey', 'California'): 1,
#  ('New Jersey', 'Nebraska'): -2,
#  ('New Jersey', 'Pennsylvania'): 0,
#  ('New Jersey', 'Michigan'): 0,
#  ('New Jersey', 'North Carolina'): 0,
#  ('New Jersey', 'Missouri'): -2,
#  ('New Jersey', 'Kentucky'): 0,
#  ('New Jersey', 'Minnesota'): 0,
#  ('New Jersey', 'Texas'): 0,
#  ('New Jersey', 'Utah'): 2,
#  ('New Jersey', 'Georgia'): 1,
#  ('New Jersey', 'Illinois'): 1,
#  ('New Jersey', 'Tennessee'): -1,
#  ('New Jersey', 'Colorado'): -1,
#  ('New Jersey', 'Indiana'): 0,
#  ('New Jersey', 'South Carolina'): 0,
#  ('New Jersey', 'Wyoming'): -3,
#  ('New Jersey', 'New York'): 0,
#  ('New Jersey', 'Arizona'): 0,
#  ('New Jersey', 'Maine'): -1,
#  ('New Jersey', 'Virginia'): 0,
#  ('New Jersey', 'Washington'): 3,
#  ('New Jersey', 'Ohio'): 0,
#  ('New Jersey', 'Nevada'): 4,
#  ('New Jersey', 'Wisconsin'): -1,
#  ('New Jersey', 'New Hampshire'): 0,
#  ('New Jersey', 'Rhode Island'): 0,
#  ('New Jersey', 'Louisiana'): -1,
#  ('New Jersey', 'Puerto Rico'): -9,
#  ('New Jersey', 'Oregon'): 1,
#  ('New Jersey', 'Vermont'): 0,
#  ('New Jersey', 'Connecticut'): 0,
#  ('New Jersey', 'Montana'): -3,
#  ('New Jersey', 'Maryland'): 0,
#  ('New Jersey', 'Iowa'): -1,
#  ('New Jersey', 'U.S. Virgin Islands'): 1,
#  ('New Jersey', 'Arkansas'): -1,
#  ('New Jersey', 'South Dakota'): -3,
#  ('New Jersey', 'Oklahoma'): -1,
#  ('New Jersey', 'Hawaii'): 12,
#  ('New Jersey', 'Alaska'): 14,
#  ('Arkansas', 'Texas'): 0,
#  ('Arkansas', 'Virginia'): 2,
#  ('Arkansas', 'North Carolina'): 2,
#  ('Arkansas', 'Florida'): 2,
#  ('Arkansas', 'Minnesota'): -1,
#  ('Arkansas', 'Georgia'): 1,
#  ('Arkansas', 'Colorado'): -2,
#  ('Arkansas', 'Illinois'): 0,
#  ('Arkansas', 'Missouri'): 0,
#  ('Arkansas', 'California'): -3,
#  ('Arkansas', 'Nevada'): -3,
#  ('Arkansas', 'Pennsylvania'): 1,
#  ('Arkansas', 'New York'): 1,
#  ('Arkansas', 'Arizona'): 0,
#  ('Arkansas', 'Michigan'): 1,
#  ('Arkansas', 'New Jersey'): 1,
#  ('Arkansas', 'Kentucky'): 1,
#  ('Virginia', 'Pennsylvania'): 0,
#  ('Virginia', 'Massachusetts'): 0,
#  ('Virginia', 'Florida'): 0,
#  ('Virginia', 'New York'): 0,
#  ('Virginia', 'Virginia'): 0,
#  ('Virginia', 'Minnesota'): -1,
#  ('Virginia', 'Colorado'): -2,
#  ('Virginia', 'Indiana'): -1,
#  ('Virginia', 'Georgia'): 0,
#  ('Virginia', 'West Virginia'): 0,
#  ('Virginia', 'Ohio'): 0,
#  ('Virginia', 'Illinois'): -1,
#  ('Virginia', 'California'): 1,
#  ('Virginia', 'New Jersey'): 0,
#  ('Virginia', 'North Carolina'): 0,
#  ('Virginia', 'Tennessee'): -1,
#  ('Virginia', 'Missouri'): -1,
#  ('Virginia', 'Maine'): 0,
#  ('Virginia', 'Nevada'): 0,
#  ('Virginia', 'Texas'): -1,
#  ('Virginia', 'South Carolina'): 0,
#  ('Virginia', 'Washington'): 0,
#  ('Virginia', 'Connecticut'): -1,
#  ('Virginia', 'New Hampshire'): 0,
#  ('Virginia', 'Alabama'): -1,
#  ('Virginia', 'Iowa'): -1,
#  ('Virginia', 'Kentucky'): 0,
#  ('Virginia', 'Rhode Island'): 0,
#  ('Virginia', 'Louisiana'): -2,
#  ('Virginia', 'Utah'): -3,
#  ('Virginia', 'Michigan'): 0,
#  ('Virginia', 'Vermont'): 0,
#  ('Virginia', 'Arkansas'): -2,
#  ('Virginia', 'Maryland'): 0,
#  ('Virginia', 'Oklahoma'): -1,
#  ('Virginia', 'Oregon'): -3,
#  ('Virginia', 'Wisconsin'): -1,
#  ('Virginia', 'Arizona'): 1,
#  ('Virginia', 'Mississippi'): -2,
#  ('Virginia', 'Puerto Rico'): -1,
#  ('Virginia', 'Hawaii'): 12,
#  ('Virginia', 'Nebraska'): -1,
#  ('Virginia', 'U.S. Virgin Islands'): 1,
#  ('Pennsylvania', 'Michigan'): 0,
#  ('Pennsylvania', 'New York'): 0,
#  ('Pennsylvania', 'Nevada'): 4,
#  ('Pennsylvania', 'California'): 4,
#  ('Pennsylvania', 'Florida'): 1,
#  ('Pennsylvania', 'Maine'): 0,
#  ('Pennsylvania', 'North Carolina'): 0,
#  ('Pennsylvania', 'Pennsylvania'): 0,
#  ('Pennsylvania', 'Illinois'): 0,
#  ('Pennsylvania', 'Georgia'): 1,
#  ('Pennsylvania', 'South Carolina'): 0,
#  ('Pennsylvania', 'Wisconsin'): -2,
#  ('Pennsylvania', 'Texas'): 0,
#  ('Pennsylvania', 'New Jersey'): 0,
#  ('Pennsylvania', 'Minnesota'): -1,
#  ('Pennsylvania', 'Alabama'): -1,
#  ('Pennsylvania', 'Missouri'): -1,
#  ('Pennsylvania', 'Virginia'): 0,
#  ('Pennsylvania', 'Ohio'): 0,
#  ('Pennsylvania', 'Massachusetts'): 0,
#  ('Pennsylvania', 'New Hampshire'): 0,
#  ('Pennsylvania', 'Maryland'): 0,
#  ('Pennsylvania', 'Connecticut'): 0,
#  ('Pennsylvania', 'Colorado'): -3,
#  ('Pennsylvania', 'Kentucky'): 0,
#  ('Pennsylvania', 'Tennessee'): 1,
#  ('Pennsylvania', 'Arizona'): -1,
#  ('Pennsylvania', 'Louisiana'): -1,
#  ('Pennsylvania', 'Oklahoma'): -1,
#  ('Pennsylvania', 'Iowa'): -1,
#  ('Pennsylvania', 'Vermont'): 0,
#  ('Pennsylvania', 'U.S. Virgin Islands'): 0,
#  ('Pennsylvania', 'West Virginia'): 0,
#  ('Pennsylvania', 'Indiana'): 0,
#  ('Pennsylvania', 'Utah'): 0,
#  ('Pennsylvania', 'Washington'): 0,
#  ('Pennsylvania', 'Nebraska'): -1,
#  ('Pennsylvania', 'Puerto Rico'): -8,
#  ('Pennsylvania', 'Rhode Island'): 0,
#  ('Pennsylvania', 'Oregon'): 15,
#  ('Pennsylvania', 'Arkansas'): -1,
#  ('Ohio', 'Colorado'): -2,
#  ('Ohio', 'Illinois'): 0,
#  ('Ohio', 'Michigan'): 0,
#  ('Ohio', 'Georgia'): 1,
#  ('Ohio', 'Nevada'): 6,
#  ('Ohio', 'Wisconsin'): -1,
#  ('Ohio', 'Pennsylvania'): 0,
#  ('Ohio', 'Maryland'): 2,
#  ('Ohio', 'Minnesota'): -2,
#  ('Ohio', 'Virginia'): 0,
#  ('Ohio', 'California'): 5,
#  ('Ohio', 'Florida'): 1,
#  ('Ohio', 'New York'): 0,
#  ('Ohio', 'Texas'): -1,
#  ('Ohio', 'Massachusetts'): 0,
#  ('Ohio', 'New Jersey'): 0,
#  ('Ohio', 'North Carolina'): 0,
#  ('Ohio', 'Louisiana'): -2,
#  ('Ohio', 'Missouri'): -1,
#  ('Ohio', 'Arizona'): -3,
#  ('Ohio', 'South Carolina'): 0,
#  ('Ohio', 'Connecticut'): 0,
#  ('Ohio', 'Tennessee'): 3,
#  ('Ohio', 'Utah'): -3,
#  ('Ohio', 'Washington'): 4,
#  ('Ohio', 'Oregon'): 15,
#  ('Texas', 'Colorado'): -1,
#  ('Texas', 'Oklahoma'): 0,
#  ('Texas', 'California'): -2,
#  ('Texas', 'Tennessee'): 0,
#  ('Texas', 'Pennsylvania'): 0,
#  ('Texas', 'Texas'): 0,
#  ('Texas', 'Illinois'): 0,
#  ('Texas', 'Arizona'): -2,
#  ('Texas', 'Alabama'): 0,
#  ('Texas', 'New Jersey'): 0,
#  ('Texas', 'Nebraska'): -1,
#  ('Texas', 'North Carolina'): 1,
#  ('Texas', 'Maryland'): 0,
#  ('Texas', 'Washington'): -2,
#  ('Texas', 'Florida'): 1,
#  ('Texas', 'Missouri'): 0,
#  ('Texas', 'Michigan'): 1,
#  ('Texas', 'Kentucky'): 1,
#  ('Texas', 'Puerto Rico'): -3,
#  ('Texas', 'Virginia'): 1,
#  ('Texas', 'Oregon'): -3,
#  ('Texas', 'Utah'): 0,
#  ('Texas', 'Nevada'): -2,
#  ('Texas', 'New Mexico'): -2,
#  ('Texas', 'New York'): 2,
#  ('Texas', 'Kansas'): 0,
#  ('Texas', 'Louisiana'): 0,
#  ('Texas', 'Minnesota'): 0,
#  ('Texas', 'Arkansas'): 0,
#  ('Texas', 'Iowa'): 0,
#  ('Texas', 'Georgia'): 1,
#  ('Texas', 'Massachusetts'): 0,
#  ('Texas', 'Ohio'): 1,
#  ('Texas', 'Mississippi'): 0,
#  ('Texas', 'South Dakota'): -1,
#  ('Texas', 'Hawaii'): 13,
#  ('Texas', 'South Carolina'): 1,
#  ('Texas', 'Montana'): -1,
#  ('Texas', 'Wisconsin'): 0,
#  ('Texas', 'Indiana'): 1,
#  ('Texas', 'Wyoming'): -2,
#  ('Texas', 'North Dakota'): 0,
#  ('Texas', 'U.S. Virgin Islands'): 2,
#  ('Texas', 'Connecticut'): -1,
#  ('Texas', 'West Virginia'): 1,
#  ('Texas', 'Idaho'): -2,
#  ('Texas', 'Alaska'): 15,
#  ('Texas', 'Rhode Island'): 2,
#  ('Arizona', 'Nevada'): 0,
#  ('Arizona', 'Washington'): -1,
#  ('Arizona', 'Texas'): 2,
#  ('Arizona', 'Pennsylvania'): 1,
#  ('Arizona', 'Missouri'): 1,
#  ('Arizona', 'California'): 0,
#  ('Arizona', 'Colorado'): 1,
#  ('Arizona', 'Indiana'): -3,
#  ('Arizona', 'Illinois'): 1,
#  ('Arizona', 'Arizona'): 0,
#  ('Arizona', 'Nebraska'): 1,
#  ('Arizona', 'Louisiana'): 1,
#  ('Arizona', 'North Carolina'): 2,
#  ('Arizona', 'Oklahoma'): 2,
#  ('Arizona', 'Oregon'): -1,
#  ('Arizona', 'Kentucky'): 3,
#  ('Arizona', 'Tennessee'): 0,
#  ('Arizona', 'Ohio'): 3,
#  ('Arizona', 'Minnesota'): 1,
#  ('Arizona', 'New York'): -2,
#  ('Arizona', 'Utah'): 1,
#  ('Arizona', 'Michigan'): 1,
#  ('Arizona', 'Iowa'): 2,
#  ('Arizona', 'New Jersey'): 0,
#  ('Arizona', 'Massachusetts'): -6,
#  ('Arizona', 'Idaho'): 2,
#  ('Arizona', 'Georgia'): 3,
#  ('Arizona', 'North Dakota'): 3,
#  ('Arizona', 'New Mexico'): 0,
#  ('Arizona', 'Montana'): 1,
#  ('Arizona', 'Florida'): 3,
#  ('Arizona', 'Wisconsin'): 0,
#  ('Arizona', 'Maryland'): 0,
#  ('Arizona', 'Hawaii'): 10,
#  ('Arizona', 'Arkansas'): 0,
#  ('Arizona', 'Virginia'): -1,
#  ('Arizona', 'South Dakota'): 2,
#  ('Arizona', 'Kansas'): 2,
#  ('Arizona', 'Wyoming'): 2,
#  ('Arizona', 'Alaska'): 10,
#  ('Connecticut', 'Georgia'): 1,
#  ('Connecticut', 'Florida'): 2,
#  ('Connecticut', 'Virginia'): 1,
#  ('Connecticut', 'Maryland'): 1,
#  ('Connecticut', 'Illinois'): 2,
#  ('Connecticut', 'North Carolina'): 2,
#  ('Connecticut', 'Michigan'): 2,
#  ('Connecticut', 'Pennsylvania'): 0,
#  ('Connecticut', 'California'): 16,
#  ('Connecticut', 'Minnesota'): -1,
#  ('Connecticut', 'Missouri'): -2,
#  ('Connecticut', 'Colorado'): -2,
#  ('Connecticut', 'Nevada'): 6,
#  ('Connecticut', 'Texas'): 1,
#  ('Connecticut', 'New Jersey'): 0,
#  ('Connecticut', 'Puerto Rico'): -8,
#  ('Connecticut', 'South Carolina'): 0,
#  ('Connecticut', 'Kentucky'): 0,
#  ('Connecticut', 'Ohio'): 0,
#  ('Maryland', 'Massachusetts'): 0,
#  ('Maryland', 'Texas'): 0,
#  ('Maryland', 'New Hampshire'): -1,
#  ('Maryland', 'Illinois'): 1,
#  ('Maryland', 'Florida'): 1,
#  ('Maryland', 'Connecticut'): -1,
#  ('Maryland', 'California'): 1,
#  ('Maryland', 'New York'): -1,
#  ('Maryland', 'Nevada'): 3,
#  ('Maryland', 'Georgia'): 1,
#  ('Maryland', 'Washington'): 3,
#  ('Maryland', 'Colorado'): 1,
#  ('Maryland', 'Minnesota'): 0,
#  ('Maryland', 'North Carolina'): 0,
#  ('Maryland', 'Missouri'): -1,
#  ('Maryland', 'Maine'): -2,
#  ('Maryland', 'Rhode Island'): 0,
#  ('Maryland', 'Pennsylvania'): 0,
#  ('Maryland', 'Michigan'): -1,
#  ('Maryland', 'Alabama'): -2,
#  ('Maryland', 'Louisiana'): -1,
#  ('Maryland', 'Kentucky'): -1,
#  ('Maryland', 'South Carolina'): 0,
#  ('Maryland', 'Tennessee'): 0,
#  ('Maryland', 'Ohio'): -2,
#  ('Maryland', 'Utah'): 0,
#  ('Maryland', 'Virginia'): 0,
#  ('Maryland', 'Puerto Rico'): 0,
#  ('Maryland', 'New Jersey'): 0,
#  ('Maryland', 'Indiana'): 0,
#  ('Maryland', 'New Mexico'): -3,
#  ('Maryland', 'Wisconsin'): -1,
#  ('Maryland', 'Arizona'): 0,
#  ('Maryland', 'Oklahoma'): -1,
#  ('Maryland', 'Oregon'): -4,
#  ('New York', 'Virginia'): 0,
#  ('New York', 'Massachusetts'): 0,
#  ('New York', 'Ohio'): 0,
#  ('New York', 'Maryland'): 1,
#  ('New York', 'Pennsylvania'): 0,
#  ('New York', 'Arizona'): 2,
#  ('New York', 'Florida'): 0,
#  ('New York', 'North Carolina'): 0,
#  ('New York', 'Illinois'): -1,
#  ('New York', 'Texas'): -2,
#  ('New York', 'Kentucky'): 0,
#  ('New York', 'Minnesota'): 0,
#  ('New York', 'California'): 3,
#  ('New York', 'Arkansas'): -1,
#  ('New York', 'Michigan'): 0,
#  ('New York', 'Maine'): -1,
#  ('New York', 'Indiana'): 0,
#  ('New York', 'New Jersey'): 0,
#  ('New York', 'Georgia'): 0,
#  ('New York', 'New York'): 0,
#  ('New York', 'South Carolina'): 0,
#  ('New York', 'Wisconsin'): -1,
#  ('New York', 'Missouri'): -1,
#  ('New York', 'Puerto Rico'): -5,
#  ('New York', 'Utah'): 4,
#  ('New York', 'Colorado'): -2,
#  ('New York', 'Oregon'): 5,
#  ('New York', 'Nevada'): 3,
#  ('New York', 'Tennessee'): -1,
#  ('New York', 'Washington'): 3,
#  ('New York', 'New Mexico'): 18,
#  ('New York', 'Vermont'): -3,
#  ('New York', 'Louisiana'): -1,
#  ('New York', 'Iowa'): -2,
#  ('New York', 'Hawaii'): 12,
#  ('New York', 'Alabama'): -1,
#  ('New York', 'U.S. Virgin Islands'): 1,
#  ('New York', 'Nebraska'): -1,
#  ('New York', 'New Hampshire'): 0,
#  ('New York', 'Wyoming'): -3,
#  ('Florida', 'Alabama'): -1,
#  ('Florida', 'North Carolina'): 1,
#  ('Florida', 'Texas'): -1,
#  ('Florida', 'Maryland'): -1,
#  ('Florida', 'Arkansas'): -2,
#  ('Florida', 'New Jersey'): 0,
#  ('Florida', 'Illinois'): -1,
#  ('Florida', 'Florida'): 0,
#  ('Florida', 'Arizona'): -3,
#  ('Florida', 'New York'): 0,
#  ('Florida', 'Colorado'): -1,
#  ('Florida', 'Missouri'): -1,
#  ('Florida', 'Michigan'): -1,
#  ('Florida', 'Georgia'): 1,
#  ('Florida', 'Virginia'): 0,
#  ('Florida', 'New Hampshire'): -1,
#  ('Florida', 'Pennsylvania'): -1,
#  ('Florida', 'Connecticut'): -2,
#  ('Florida', 'Wisconsin'): -1,
#  ('Florida', 'Tennessee'): 0,
#  ('Florida', 'Puerto Rico'): -3,
#  ('Florida', 'Massachusetts'): 0,
#  ('Florida', 'Rhode Island'): -3,
#  ('Florida', 'California'): 2,
#  ('Florida', 'Louisiana'): -1,
#  ('Florida', 'Kentucky'): -1,
#  ('Florida', 'Ohio'): -1,
#  ('Florida', 'South Carolina'): 0,
#  ('Florida', 'Oregon'): -4,
#  ('Florida', 'Minnesota'): -2,
#  ('Florida', 'Mississippi'): -1,
#  ('Florida', 'Nevada'): 7,
#  ('Florida', 'Utah'): 10,
#  ('Florida', 'Iowa'): -1,
#  ('Florida', 'Indiana'): 0,
#  ('Florida', 'Oklahoma'): -1,
#  ('Florida', 'Maine'): 0,
#  ('Florida', 'U.S. Virgin Islands'): 1,
#  ('Florida', 'Washington'): 1,
#  ('Florida', 'Nebraska'): -3,
#  ('Florida', 'North Dakota'): -1,
#  ('Florida', 'New Mexico'): -1,
#  ('Florida', 'South Dakota'): -2,
#  ('Florida', 'West Virginia'): 0,
#  ('Florida', 'Vermont'): 0,
#  ('Washington', 'Alaska'): -3,
#  ('Washington', 'Nevada'): 0,
#  ('Washington', 'California'): 0,
#  ('Washington', 'Arizona'): 1,
#  ('Washington', 'North Carolina'): 0,
#  ('Washington', 'Virginia'): 0,
#  ('Washington', 'Washington'): 0,
#  ('Washington', 'Montana'): -1,
#  ('Washington', 'Massachusetts'): -4,
#  ('Washington', 'Florida'): -1,
#  ('Washington', 'Oregon'): -1,
#  ('Washington', 'Idaho'): 2,
#  ('Washington', 'Michigan'): 0,
#  ('Washington', 'Colorado'): 2,
#  ('Washington', 'Illinois'): 0,
#  ('Washington', 'Utah'): 1,
#  ('Washington', 'Wisconsin'): 3,
#  ('Washington', 'Pennsylvania'): 0,
#  ('Washington', 'New Jersey'): -3,
#  ('Washington', 'Georgia'): -1,
#  ('Washington', 'Texas'): 2,
#  ('Washington', 'Minnesota'): 3,
#  ('Washington', 'Missouri'): 1,
#  ('Washington', 'New York'): -3,
#  ('Washington', 'New Mexico'): 1,
#  ('Washington', 'Hawaii'): 5,
#  ('Washington', 'Maryland'): -3,
#  ('Washington', 'Tennessee'): 3,
#  ('Washington', 'Indiana'): 4,
#  ('Washington', 'Nebraska'): 3,
#  ('Washington', 'South Carolina'): 5,
#  ('Washington', 'Kansas'): 3,
#  ('Washington', 'Oklahoma'): 3,
#  ('Washington', 'Louisiana'): -1,
#  ('Washington', 'Ohio'): -4,
#  ('Washington', 'Kentucky'): -16,
#  ('Washington', 'Wyoming'): 1,
#  ('Utah', 'New York'): -4,
#  ('Utah', 'California'): -1,
#  ('Utah', 'Montana'): 0,
#  ('Utah', 'Michigan'): 3,
#  ('Utah', 'Missouri'): -2,
#  ('Utah', 'Nevada'): -1,
#  ('Utah', 'Maryland'): 0,
#  ('Utah', 'Colorado'): 0,
#  ('Utah', 'Florida'): -10,
#  ('Utah', 'Wyoming'): 0,
#  ('Utah', 'Arizona'): -1,
#  ('Utah', 'New Jersey'): -2,
#  ('Utah', 'North Carolina'): 3,
#  ('Utah', 'Texas'): 0,
#  ('Utah', 'Illinois'): 1,
#  ('Utah', 'Washington'): -1,
#  ('Utah', 'Idaho'): 0,
#  ('Utah', 'Virginia'): 3,
#  ('Utah', 'Oregon'): -1,
#  ('Utah', 'Utah'): 0,
#  ('Utah', 'Georgia'): 2,
#  ('Utah', 'Louisiana'): 1,
#  ('Utah', 'Pennsylvania'): 0,
#  ('Utah', 'South Dakota'): 1,
#  ('Utah', 'Wisconsin'): 1,
#  ('Utah', 'Massachusetts'): -7,
#  ('Utah', 'Minnesota'): -1,
#  ('Utah', 'Ohio'): 3,
#  ('Utah', 'Tennessee'): 1,
#  ('Utah', 'Kentucky'): 3,
#  ('Utah', 'Indiana'): 3,
#  ('Utah', 'New Mexico'): 0,
#  ('Utah', 'Oklahoma'): 2,
#  ('Utah', 'Nebraska'): 0,
#  ('Utah', 'Hawaii'): 15,
#  ('Utah', 'Iowa'): -5,
#  ('Utah', 'Alaska'): -3,
#  ('New Mexico', 'New York'): -18,
#  ('New Mexico', 'Texas'): 2,
#  ('New Mexico', 'Colorado'): 0,
#  ('New Mexico', 'California'): 0,
#  ('New Mexico', 'Arizona'): 0,
#  ('New Mexico', 'Nevada'): 0,
#  ('New Mexico', 'Washington'): -1,
#  ('New Mexico', 'Illinois'): 2,
#  ('New Mexico', 'Oregon'): -2,
#  ('New Mexico', 'Georgia'): 3,
#  ('New Mexico', 'Missouri'): 1,
#  ('New Mexico', 'Utah'): 0,
#  ('New Mexico', 'Minnesota'): 1,
#  ('New Mexico', 'Maryland'): 3,
#  ('New Mexico', 'Florida'): 1,
#  ('Colorado', 'Texas'): 1,
#  ('Colorado', 'California'): -1,
#  ('Colorado', 'New York'): 2,
#  ('Colorado', 'North Carolina'): 1,
#  ('Colorado', 'Florida'): 1,
#  ('Colorado', 'Georgia'): 2,
#  ('Colorado', 'Virginia'): 2,
#  ('Colorado', 'Arizona'): -1,
#  ('Colorado', 'Nebraska'): 1,
#  ('Colorado', 'Utah'): 0,
#  ('Colorado', 'Oklahoma'): 2,
#  ('Colorado', 'Massachusetts'): -1,
#  ('Colorado', 'Washington'): -2,
#  ('Colorado', 'Connecticut'): 2,
#  ('Colorado', 'Colorado'): 0,
#  ('Colorado', 'Missouri'): 1,
#  ('Colorado', 'Illinois'): 1,
#  ('Colorado', 'Montana'): 0,
#  ('Colorado', 'Nevada'): -1,
#  ('Colorado', 'Wyoming'): 0,
#  ('Colorado', 'North Dakota'): 1,
#  ('Colorado', 'Kansas'): 2,
#  ('Colorado', 'Ohio'): 2,
#  ('Colorado', 'Kentucky'): 3,
#  ('Colorado', 'Idaho'): -2,
#  ('Colorado', 'New Mexico'): 0,
#  ('Colorado', 'Michigan'): 1,
#  ('Colorado', 'Tennessee'): 1,
#  ('Colorado', 'Oregon'): -2,
#  ('Colorado', 'Maryland'): -1,
#  ('Colorado', 'Hawaii'): 15,
#  ('Colorado', 'Pennsylvania'): 3,
#  ('Colorado', 'New Jersey'): 1,
#  ('Colorado', 'Wisconsin'): 0,
#  ('Colorado', 'Indiana'): 1,
#  ('Colorado', 'Mississippi'): 1,
#  ('Colorado', 'Arkansas'): 2,
#  ('Colorado', 'South Dakota'): 1,
#  ('Colorado', 'Iowa'): 1,
#  ('Colorado', 'Louisiana'): 1,
#  ('Colorado', 'Minnesota'): 1,
#  ('Colorado', 'Alabama'): 1,
#  ('Colorado', 'Alaska'): 15,
#  ('Colorado', 'South Carolina'): 2,
#  ('Colorado', 'Rhode Island'): -8,
#  ('Colorado', 'Maine'): 0,
#  ('Colorado', 'Vermont'): 3,
#  ('Oregon', 'Washington'): 1,
#  ('Oregon', 'Colorado'): 2,
#  ('Oregon', 'California'): 1,
#  ('Oregon', 'New Jersey'): -1,
#  ('Oregon', 'Alaska'): -1,
#  ('Oregon', 'Minnesota'): 3,
#  ('Oregon', 'Utah'): 1,
#  ('Oregon', 'Oregon'): 0,
#  ('Oregon', 'Idaho'): -1,
#  ('Oregon', 'Illinois'): -1,
#  ('Oregon', 'Arizona'): 1,
#  ('Oregon', 'Nevada'): 1,
#  ('Oregon', 'Hawaii'): -1,
#  ('Oregon', 'Georgia'): -3,
#  ('Oregon', 'Virginia'): 3,
#  ('Oregon', 'Texas'): 3,
#  ('Oregon', 'Montana'): 2,
#  ('Oregon', 'New York'): -5,
#  ('Oregon', 'New Mexico'): 2,
#  ('Oregon', 'Florida'): 4,
#  ('Oregon', 'Missouri'): 3,
#  ('Oregon', 'Massachusetts'): -3,
#  ('Oregon', 'Michigan'): -5,
#  ('Oregon', 'North Carolina'): -15,
#  ('Oregon', 'Ohio'): -15,
#  ('Oregon', 'Maryland'): 4,
#  ('Oregon', 'Nebraska'): 3,
#  ('Oregon', 'Pennsylvania'): -15,
#  ('Oregon', 'Wisconsin'): 3,
#  ('Georgia', 'Ohio'): -1,
#  ('Georgia', 'New York'): 0,
#  ('Georgia', 'Minnesota'): -2,
#  ('Georgia', 'California'): -1,
#  ('Georgia', 'Indiana'): -1,
#  ('Georgia', 'Utah'): -2,
#  ('Georgia', 'Georgia'): 0,
#  ('Georgia', 'North Carolina'): 0,
#  ('Georgia', 'Texas'): -1,
#  ('Georgia', 'New Jersey'): -1,
#  ('Georgia', 'Mississippi'): -2,
#  ('Georgia', 'Virginia'): 0,
#  ('Georgia', 'Florida'): -1,
#  ('Georgia', 'Pennsylvania'): -1,
#  ('Georgia', 'West Virginia'): 0,
#  ('Georgia', 'Tennessee'): -1,
#  ('Georgia', 'Illinois'): -1,
#  ('Georgia', 'Kentucky'): 0,
#  ('Georgia', 'Massachusetts'): -1,
#  ('Georgia', 'Arkansas'): -1,
#  ('Georgia', 'Louisiana'): -2,
#  ('Georgia', 'Nevada'): -2,
#  ('Georgia', 'Maine'): 0,
#  ('Georgia', 'South Carolina'): -1,
#  ('Georgia', 'Alabama'): -2,
#  ('Georgia', 'Colorado'): -2,
#  ('Georgia', 'Nebraska'): -2,
#  ('Georgia', 'Arizona'): -3,
#  ('Georgia', 'Wisconsin'): -2,
#  ('Georgia', 'Missouri'): -2,
#  ('Georgia', 'Michigan'): -1,
#  ('Georgia', 'Oregon'): 3,
#  ('Georgia', 'Connecticut'): -1,
#  ('Georgia', 'Iowa'): -2,
#  ('Georgia', 'Washington'): 1,
#  ('Georgia', 'Maryland'): -1,
#  ('Georgia', 'Puerto Rico'): 0,
#  ('Georgia', 'Oklahoma'): -1,
#  ('Georgia', 'Rhode Island'): 0,
#  ('Georgia', 'New Hampshire'): 0,
#  ('Georgia', 'U.S. Virgin Islands'): 0,
#  ('Georgia', 'New Mexico'): -3,
#  ('Georgia', 'Kansas'): -2,
#  ('Georgia', 'Vermont'): -1,
#  ('Georgia', 'Hawaii'): 12,
#  ('Georgia', 'South Dakota'): -1,
#  ('Georgia', 'Montana'): 0,
#  ('Georgia', 'Alaska'): 14,
#  ('Georgia', 'Wyoming'): -5,
#  ('Georgia', 'North Dakota'): -2,
#  ('Missouri', 'Colorado'): -1,
#  ('Missouri', 'Wisconsin'): 0,
#  ('Missouri', 'Illinois'): 0,
#  ('Missouri', 'Virginia'): 1,
#  ('Missouri', 'Georgia'): 2,
#  ('Missouri', 'Texas'): 0,
#  ('Missouri', 'Ohio'): 1,
#  ('Missouri', 'North Carolina'): 2,
#  ('Missouri', 'Nevada'): 1,
#  ('Missouri', 'Michigan'): 2,
#  ('Missouri', 'Maryland'): 1,
#  ('Missouri', 'California'): -1,
#  ('Missouri', 'Florida'): 1,
#  ('Missouri', 'Kentucky'): 1,
#  ('Missouri', 'New Jersey'): 2,
#  ('Missouri', 'Pennsylvania'): 1,
#  ('Missouri', 'Oregon'): -3,
#  ('Missouri', 'New York'): 1,
#  ('Missouri', 'Minnesota'): 0,
#  ('Missouri', 'Massachusetts'): 0,
#  ('Missouri', 'Louisiana'): 0,
#  ('Missouri', 'Indiana'): 0,
#  ('Missouri', 'Iowa'): 0,
#  ('Missouri', 'Tennessee'): 0,
#  ('Missouri', 'Arizona'): -1,
#  ('Missouri', 'Arkansas'): 0,
#  ('Missouri', 'Washington'): -1,
#  ('Missouri', 'Missouri'): 0,
#  ('Missouri', 'Oklahoma'): 0,
#  ('Missouri', 'New Mexico'): -1,
#  ('Missouri', 'Utah'): 2,
#  ('Missouri', 'Nebraska'): 0,
#  ('Missouri', 'Kansas'): 0,
#  ('Missouri', 'South Carolina'): 1,
#  ('Missouri', 'Connecticut'): 2,
#  ('Tennessee', 'Texas'): 0,
#  ('Tennessee', 'New York'): 1,
#  ('Tennessee', 'Illinois'): 0,
#  ('Tennessee', 'Florida'): 0,
#  ('Tennessee', 'Wisconsin'): -1,
#  ('Tennessee', 'California'): 0,
#  ('Tennessee', 'Colorado'): -1,
#  ('Tennessee', 'Michigan'): 0,
#  ('Tennessee', 'Minnesota'): 0,
#  ('Tennessee', 'Nevada'): 1,
#  ('Tennessee', 'North Carolina'): 0,
#  ('Tennessee', 'Georgia'): 1,
#  ('Tennessee', 'Massachusetts'): -1,
#  ('Tennessee', 'Louisiana'): 0,
#  ('Tennessee', 'South Carolina'): 2,
#  ('Tennessee', 'New Jersey'): 1,
#  ('Tennessee', 'Virginia'): 1,
#  ('Tennessee', 'Pennsylvania'): -1,
#  ('Tennessee', 'Maryland'): 0,
#  ('Tennessee', 'Ohio'): -3,
#  ('Tennessee', 'Missouri'): 0,
#  ('Tennessee', 'Arizona'): 0,
#  ('Tennessee', 'Washington'): -3,
#  ('Tennessee', 'Kentucky'): 2,
#  ('Tennessee', 'Utah'): -1,
#  ('Tennessee', 'Iowa'): 0,
#  ('Alaska', 'Washington'): 3,
#  ('Alaska', 'Alaska'): 0,
#  ('Alaska', 'Minnesota'): -10,
#  ('Alaska', 'Oregon'): 1,
#  ('Alaska', 'Colorado'): -15,
#  ('Alaska', 'Illinois'): -15,
#  ('Alaska', 'California'): 0,
#  ('Alaska', 'New Jersey'): -14,
#  ('Alaska', 'Texas'): -15,
#  ('Alaska', 'Arizona'): -10,
#  ('Alaska', 'Georgia'): -14,
#  ('Alaska', 'Hawaii'): 15,
#  ('Alaska', 'Utah'): 3,
#  ('Minnesota', 'Illinois'): 0,
#  ('Minnesota', 'Virginia'): 1,
#  ('Minnesota', 'Nebraska'): 0,
#  ('Minnesota', 'California'): -2,
#  ('Minnesota', 'Washington'): -3,
#  ('Minnesota', 'Nevada'): -3,
#  ('Minnesota', 'Florida'): 2,
#  ('Minnesota', 'North Dakota'): -1,
#  ('Minnesota', 'Michigan'): 1,
#  ('Minnesota', 'New Jersey'): 0,
#  ('Minnesota', 'Missouri'): 0,
#  ('Minnesota', 'Indiana'): 2,
#  ('Minnesota', 'Texas'): 0,
#  ('Minnesota', 'Georgia'): 2,
#  ('Minnesota', 'New York'): 0,
#  ('Minnesota', 'Wisconsin'): 0,
#  ('Minnesota', 'Arizona'): -1,
#  ('Minnesota', 'Ohio'): 2,
#  ('Minnesota', 'Tennessee'): 0,
#  ('Minnesota', 'Minnesota'): 0,
#  ('Minnesota', 'Maryland'): 0,
#  ('Minnesota', 'Utah'): 1,
#  ('Minnesota', 'Colorado'): -1,
#  ('Minnesota', 'North Carolina'): 2,
#  ('Minnesota', 'South Dakota'): -1,
#  ('Minnesota', 'Iowa'): 0,
#  ('Minnesota', 'Kansas'): 0,
#  ('Minnesota', 'Alaska'): 10,
#  ('Minnesota', 'Kentucky'): 1,
#  ('Minnesota', 'Montana'): -2,
#  ('Minnesota', 'Oregon'): -3,
#  ('Minnesota', 'Louisiana'): 0,
#  ('Minnesota', 'Connecticut'): 1,
#  ('Minnesota', 'Massachusetts'): 0,
#  ('Minnesota', 'Oklahoma'): 0,
#  ('Minnesota', 'Pennsylvania'): 1,
#  ('Minnesota', 'Idaho'): -1,
#  ('Minnesota', 'Arkansas'): 1,
#  ('Minnesota', 'Hawaii'): 13,
#  ('Minnesota', 'New Mexico'): -1,
#  ('Minnesota', 'South Carolina'): 2,
#  ('Minnesota', 'Wyoming'): -2,
#  ('Minnesota', 'Puerto Rico'): 1,
#  ('Maine', 'Virginia'): 0,
#  ('Maine', 'Pennsylvania'): 0,
#  ('Maine', 'New York'): 1,
#  ('Maine', 'Georgia'): 0,
#  ('Maine', 'Maryland'): 2,
#  ('Maine', 'New Jersey'): 1,
#  ('Maine', 'Illinois'): -1,
#  ('Maine', 'Michigan'): 0,
#  ('Maine', 'North Carolina'): 0,
#  ('Maine', 'Florida'): 0,
#  ('Maine', 'Colorado'): 0,
#  ('Nebraska', 'Colorado'): -1,
#  ('Nebraska', 'Minnesota'): 0,
#  ('Nebraska', 'Texas'): 1,
#  ('Nebraska', 'California'): -3,
#  ('Nebraska', 'Nevada'): 1,
#  ('Nebraska', 'Illinois'): 0,
#  ('Nebraska', 'North Carolina'): 1,
#  ('Nebraska', 'Utah'): 0,
#  ('Nebraska', 'Georgia'): 2,
#  ('Nebraska', 'Virginia'): 1,
#  ('Nebraska', 'Missouri'): 0,
#  ('Nebraska', 'New York'): 1,
#  ('Nebraska', 'Pennsylvania'): 1,
#  ('Nebraska', 'Washington'): -3,
#  ('Nebraska', 'Arizona'): -1,
#  ('Nebraska', 'New Jersey'): 2,
#  ('Nebraska', 'Michigan'): 2,
#  ('Nebraska', 'Florida'): 3,
#  ('Nebraska', 'Oregon'): -3,
#  ('Hawaii', 'Hawaii'): 0,
#  ('Hawaii', 'California'): -2,
#  ('Hawaii', 'Colorado'): -15,
#  ('Hawaii', 'Arizona'): -10,
#  ('Hawaii', 'Washington'): -5,
#  ('Hawaii', 'Michigan'): -11,
#  ('Hawaii', 'Alaska'): -15,
#  ('Hawaii', 'Oregon'): 1,
#  ('Hawaii', 'Virginia'): -12,
#  ('Hawaii', 'Texas'): -13,
#  ('Hawaii', 'Illinois'): -13,
#  ('Hawaii', 'Nevada'): -4,
#  ('Hawaii', 'Utah'): -15,
#  ('Hawaii', 'Minnesota'): -13,
#  ('Hawaii', 'New Jersey'): -12,
#  ('Hawaii', 'New York'): -12,
#  ('Hawaii', 'Georgia'): -12,
#  ('Hawaii', 'U.S. Pacific Trust Territories and Possessions'): -1,
#  ('Hawaii', 'Massachusetts'): -11,
#  ('Nevada', 'Michigan'): -1,
#  ('Nevada', 'Utah'): 1,
#  ('Nevada', 'California'): 0,
#  ('Nevada', 'Texas'): 2,
#  ('Nevada', 'Arizona'): 0,
#  ('Nevada', 'Georgia'): 2,
#  ('Nevada', 'Wisconsin'): 0,
#  ('Nevada', 'Florida'): -7,
#  ('Nevada', 'Colorado'): 1,
#  ('Nevada', 'Kentucky'): -5,
#  ('Nevada', 'New Jersey'): -4,
#  ('Nevada', 'Washington'): 0,
#  ('Nevada', 'Missouri'): -1,
#  ('Nevada', 'New York'): -3,
#  ('Nevada', 'Illinois'): 0,
#  ('Nevada', 'Tennessee'): -1,
#  ('Nevada', 'Oregon'): -1,
#  ('Nevada', 'Maryland'): -3,
#  ('Nevada', 'Nevada'): 0,
#  ('Nevada', 'North Carolina'): -1,
#  ('Nevada', 'Virginia'): 0,
#  ('Nevada', 'Minnesota'): 3,
#  ('Nevada', 'Louisiana'): -4,
#  ('Nevada', 'Pennsylvania'): -4,
#  ('Nevada', 'South Dakota'): 3,
#  ('Nevada', 'Alabama'): -1,
#  ('Nevada', 'North Dakota'): 3,
#  ('Nevada', 'Arkansas'): 3,
#  ('Nevada', 'Ohio'): -6,
#  ('Nevada', 'Indiana'): -2,
#  ('Nevada', 'Connecticut'): -6,
#  ('Nevada', 'Massachusetts'): -1,
#  ('Nevada', 'Montana'): 2,
#  ('Nevada', 'Nebraska'): -1,
#  ('Nevada', 'Iowa'): 3,
#  ('Nevada', 'Oklahoma'): 1,
#  ('Nevada', 'Hawaii'): 4,
#  ('Nevada', 'Idaho'): 1,
#  ('Nevada', 'New Mexico'): 0,
#  ('Nevada', 'Kansas'): 3,
#  ('Nevada', 'South Carolina'): 8,
#  ('Alabama', 'Virginia'): 1,
#  ('Alabama', 'Texas'): 0,
#  ('Alabama', 'Illinois'): 0,
#  ('Alabama', 'North Carolina'): 2,
#  ('Alabama', 'Georgia'): 2,
#  ('Alabama', 'New York'): 1,
#  ('Alabama', 'Colorado'): -1,
#  ('Alabama', 'Nevada'): 1,
#  ('Alabama', 'Florida'): 1,
#  ('Alabama', 'Maryland'): 2,
#  ('Alabama', 'Michigan'): 2,
#  ('Alabama', 'Pennsylvania'): 1,
#  ('Montana', 'Colorado'): 0,
#  ('Montana', 'Utah'): 0,
#  ('Montana', 'Washington'): 1,
#  ('Montana', 'Illinois'): 1,
#  ('Montana', 'Minnesota'): 2,
#  ('Montana', 'Texas'): 1,
#  ('Montana', 'California'): -1,
#  ('Montana', 'Nevada'): -2,
#  ('Montana', 'Oregon'): -2,
#  ('Montana', 'Arizona'): -1,
#  ('Montana', 'Georgia'): 0,
#  ('Montana', 'New Jersey'): 3,
#  ('North Dakota', 'Nevada'): -3,
#  ('North Dakota', 'Minnesota'): 1,
#  ('North Dakota', 'North Dakota'): 0,
#  ('North Dakota', 'Texas'): 0,
#  ('North Dakota', 'Colorado'): -1,
#  ...}

# %%
# time_delay를 통해 time_diff를 계산하기 위해  먼저 time_diff 컬럼 생성 
df['time_diff'] = np.nan


# 구한 시차를 df에 time_diff 컬럼에 넣어주기 
for i in range(len(df)):   
    if (df['Origin_State'].iloc[i],df['Destination_State'].iloc[i]) in time_delay.keys() :
        df['time_diff'].iloc[i] = time_delay[df['Origin_State'].iloc[i],df['Destination_State'].iloc[i]]
    else : 
        df['time_diff'].iloc[i] == 'time'
# Out:
# C:\Users\efkje\AppData\Local\Temp\ipykernel_32416\3737956516.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time_diff'].iloc[i] = time_delay[df['Origin_State'].iloc[i],df['Destination_State'].iloc[i]]

# %%
df = df.dropna(subset=['time_diff'])
df['time_diff'].unique()
# Out:
# array([ -1.,   0.,  -2.,   1.,  -4.,   3.,   2.,   4.,  -3.,   6.,  -7.,
#         -5., -10.,   5.,  15.,  10.,  18.,  13.,   9.,   7.,  -6.,   8.,
#         11.,  16.,  -9.,  12., -15.,  -8.,  14.])

# %%
#시차 고려하지 않은 도착시간-출발시간
df['flight_time'] = (df['Estimated_Arrival_Time']-df['Estimated_Departure_Time'])

# %%
#도착시간-출발시간 분으로 표현
df['flight_time'] = (df['flight_time']//100)*60 + df['flight_time']%100

# %%
#시차 포함
df['flight_time'] = df['flight_time'] - df['time_diff']*60

# %%
df[df['time_diff']==18]
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 3777    TRAIN_003777                    1953.0                  2302.0
# 27690   TRAIN_027690                    1955.0                  2309.0
# 47752   TRAIN_047752                    2000.0                  2305.0
# 94901   TRAIN_094901                    1943.0                  2254.0
# 97441   TRAIN_097441                    2000.0                  2305.0
# 99205   TRAIN_099205                    1942.0                  2254.0
# 151171  TRAIN_151171                    2000.0                  2305.0
# 159232  TRAIN_159232                    1953.0                  2302.0
# 231202  TRAIN_231202                    2000.0                  2300.0
# 249306  TRAIN_249306                    2000.0                  2307.0
# 317708  TRAIN_317708                    2000.0                  2309.0
# 333958  TRAIN_333958                    1942.0                  2254.0
# 336671  TRAIN_336671                    2000.0                  2305.0
# 338718  TRAIN_338718                    1943.0                  2254.0
# 351252  TRAIN_351252                    1957.0                  2308.0
# 379779  TRAIN_379779                    2000.0                  2300.0
# 384094  TRAIN_384094                    1955.0                  2309.0
# 395750  TRAIN_395750                    2000.0                  2305.0
# 442851  TRAIN_442851                    2000.0                  2257.0
# 463621  TRAIN_463621                    2000.0                  2305.0
# 477800  TRAIN_477800                    1958.0                  2308.0
# 508869  TRAIN_508869                    1945.0                  2304.0
# 526797  TRAIN_526797                    2000.0                  2309.0
# 547691  TRAIN_547691                    2000.0                  2305.0
# 579801  TRAIN_579801                    1953.0                  2307.0
# 590921  TRAIN_590921                    2000.0                  2309.0
# 617731  TRAIN_617731                    1937.0                  2259.0
# 651632  TRAIN_651632                    2000.0                  2309.0
# 675961  TRAIN_675961                    1940.0                  2240.0
# 676500  TRAIN_676500                    1959.0                  2308.0
# 693582  TRAIN_693582                    1950.0                  2302.0
# 695325  TRAIN_695325                    1937.0                  2259.0
# 725735  TRAIN_725735                    2000.0                  2305.0
# 741725  TRAIN_741725                    2000.0                  2300.0
# 790442  TRAIN_790442                    1950.0                  2300.0
# 804069  TRAIN_804069                    2000.0                  2305.0
# 822211  TRAIN_822211                    2000.0                  2300.0
# 836233  TRAIN_836233                    1943.0                  2254.0
# 873906  TRAIN_873906                    1959.0                  2308.0
# 911911  TRAIN_911911                    1940.0                  2306.0
# 956751  TRAIN_956751                    1937.0                  2259.0
# 968202  TRAIN_968202                    1937.0                  2253.0
# 992188  TRAIN_992188                    1955.0                  2309.0
#
#        Origin_State Destination_State  Distance  Delay  time_diff  flight_time
# 3777       New York        New Mexico    1826.0    0.0       18.0       -851.0
# 27690      New York        New Mexico    1826.0    NaN       18.0       -846.0
# 47752      New York        New Mexico    1826.0    NaN       18.0       -895.0
# 94901      New York        New Mexico    1826.0    NaN       18.0       -889.0
# 97441      New York        New Mexico    1826.0    NaN       18.0       -895.0
# 99205      New York        New Mexico    1826.0    NaN       18.0       -888.0
# 151171     New York        New Mexico    1826.0    NaN       18.0       -895.0
# 159232     New York        New Mexico    1826.0    1.0       18.0       -851.0
# 231202     New York        New Mexico    1826.0    NaN       18.0       -900.0
# 249306     New York        New Mexico    1826.0    0.0       18.0       -893.0
# 317708     New York        New Mexico    1826.0    NaN       18.0       -891.0
# 333958     New York        New Mexico    1826.0    NaN       18.0       -888.0
# 336671     New York        New Mexico    1826.0    NaN       18.0       -895.0
# 338718     New York        New Mexico    1826.0    1.0       18.0       -889.0
# 351252     New York        New Mexico    1826.0    1.0       18.0       -849.0
# 379779     New York        New Mexico    1826.0    0.0       18.0       -900.0
# 384094     New York        New Mexico    1826.0    0.0       18.0       -846.0
# 395750     New York        New Mexico    1826.0    0.0       18.0       -895.0
# 442851     New York        New Mexico    1826.0    0.0       18.0       -903.0
# 463621     New York        New Mexico    1826.0    NaN       18.0       -895.0
# 477800     New York        New Mexico    1826.0    NaN       18.0       -850.0
# 508869     New York        New Mexico    1826.0    NaN       18.0       -841.0
# 526797     New York        New Mexico    1826.0    1.0       18.0       -891.0
# 547691     New York        New Mexico    1826.0    0.0       18.0       -895.0
# 579801     New York        New Mexico    1826.0    NaN       18.0       -846.0
# 590921     New York        New Mexico    1826.0    NaN       18.0       -891.0
# 617731     New York        New Mexico    1826.0    NaN       18.0       -878.0
# 651632     New York        New Mexico    1826.0    0.0       18.0       -891.0
# 675961     New York        New Mexico    1826.0    NaN       18.0       -900.0
# 676500     New York        New Mexico    1826.0    1.0       18.0       -851.0
# 693582     New York        New Mexico    1826.0    NaN       18.0       -848.0
# 695325     New York        New Mexico    1826.0    NaN       18.0       -878.0
# 725735     New York        New Mexico    1826.0    NaN       18.0       -895.0
# 741725     New York        New Mexico    1826.0    NaN       18.0       -900.0
# 790442     New York        New Mexico    1826.0    NaN       18.0       -850.0
# 804069     New York        New Mexico    1826.0    NaN       18.0       -895.0
# 822211     New York        New Mexico    1826.0    0.0       18.0       -900.0
# 836233     New York        New Mexico    1826.0    NaN       18.0       -889.0
# 873906     New York        New Mexico    1826.0    NaN       18.0       -851.0
# 911911     New York        New Mexico    1826.0    0.0       18.0       -834.0
# 956751     New York        New Mexico    1826.0    NaN       18.0       -878.0
# 968202     New York        New Mexico    1826.0    NaN       18.0       -884.0
# 992188     New York        New Mexico    1826.0    NaN       18.0       -846.0

# %%
#우선 flight_time 양수인 부분만 ???
df = df[df['flight_time']>0]

# %%
#거리 1마일당 비행시간 
distance_time = (df['flight_time']/df['Distance']).mean()
distance_time

# %%
#train_df에 df 시차와 비행시간 컬럼 넣어주기 
train_df = pd.merge(train_df, df, how='outer')
train_df

# %% [markdown]
# 비행시간 컬럼 추가

# %%
#거리 별 비행시간 - 평균비행시간 컬럼 추가 
train_df['flight_time_avg'] = round(train_df['Distance']*distance_time)

# %%
#비행시간차이 = 비행시간- 평균비행시간
train_df['flight_time_diff'] = train_df['flight_time'] - train_df['flight_time_avg']

# %%
train_df

# %%
#여기서 부터 .항공사별 비행시간과 비행시간차이 비교
#출발공항 기준
train_df.groupby('Origin_Airport').mean()

# %%
train_df.groupby('Destination_Airport').mean()

# %% [markdown]
# 먼저 공항별로 group 묶고 -> 평균비행시간 -> 평균비행시간과 비행시간 차이

# %%
#도착예정시간, 출발예정시간 둘 중 하나만 나와있는 걸로 거리가 있으니 데이터 채우기
