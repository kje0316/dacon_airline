# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import math
import json
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from IPython.display import Image
import seaborn as sns

# %%
#진행상황
# !pip install tqdm
import time
from tqdm import tqdm

# for i in tqdm(range(10)):
# #     time.sleep(0.1)
# empty_list = []
# for word in tqdm(['apple', 'ball', 'cat', 'doll', 'egg'], desc='iterate list'):
#     time.sleep(0.1)
#     empty_list.append(word)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (4.65.0)

# %% [markdown]
# #과정
# 1. 데이터 탐색(EDA)
#  - 데이터 분포 조사(히스토그램, 데이터 수, 이상치 조사, 결측치)
#  - 데이터 타입 확인
#  - 데이터 상관 관계(joint plot, heatmap)
#  - 데이터 시각화
#
# 2. 데이터 전처리(수치형 데이터 기준)
#  - 결측치 처리(drop, imputation(결측값 대체))
#  - 이상치 처리(정규분포, box plot, ML)
#  - 스케일링
#
# 3. 데이터 분할(data split) - train,test 데이터가 나뉘어져있으므로 할 필요x
#
# 4. 모델 구축
#  - 모델 선택
#  - 모델 하이퍼 파라미터 설정
#
# 5. 학습
#  - cost(mse, cross entropy)
#  - 학습 방법(grid search, 경사하강법)
#
# 6. 검증
#  - 평가지표
#  - 하이퍼 파라미터 튜닝
#  - cross validation

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
sample_df = pd.read_csv('sample_submission.csv')

# %%
train_df.head(2)
# Out:
#              ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 0  TRAIN_000000      4            15                       NaN
# 1  TRAIN_000001      8            15                     740.0
#
#    Estimated_Arrival_Time  Cancelled  Diverted Origin_Airport  \
# 0                     NaN          0         0            OKC
# 1                  1024.0          0         0            ORD
#
#    Origin_Airport_ID Origin_State Destination_Airport  Destination_Airport_ID  \
# 0              13851     Oklahoma                 HOU                   12191
# 1              13930     Illinois                 SLC                   14869
#
#   Destination_State  Distance                 Airline Carrier_Code(IATA)  \
# 0             Texas     419.0  Southwest Airlines Co.                 WN
# 1              Utah    1250.0   SkyWest Airlines Inc.                 UA
#
#    Carrier_ID(DOT) Tail_Number Delay
# 0          19393.0      N7858A   NaN
# 1          20304.0      N125SY   NaN

# %%
test_df.head(2)
# Out:
#             ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 0  TEST_000000     12            16                    1156.0
# 1  TEST_000001      9            12                    1500.0
#
#    Estimated_Arrival_Time  Cancelled  Diverted Origin_Airport  \
# 0                     NaN          0         0            IAH
# 1                  1715.0          0         0            EWR
#
#    Origin_Airport_ID Origin_State Destination_Airport  Destination_Airport_ID  \
# 0              12266        Texas                 SAT                   14683
# 1              11618   New Jersey                 ATL                   10397
#
#   Destination_State  Distance                Airline Carrier_Code(IATA)  \
# 0             Texas     191.0  United Air Lines Inc.                 UA
# 1               NaN     746.0   Delta Air Lines Inc.                 DL
#
#    Carrier_ID(DOT) Tail_Number
# 0              NaN      N79402
# 1          19790.0       N3765

# %%
sample_df.head() #Delayed가 전부 1인데 무슨 의미일까
# Out:
#             ID  Not_Delayed  Delayed
# 0  TEST_000000            0        1
# 1  TEST_000001            0        1
# 2  TEST_000002            0        1
# 3  TEST_000003            0        1
# 4  TEST_000004            0        1

# %%
#train_df 먼저

# %%
train_df.head(3)
# Out:
#              ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 0  TRAIN_000000      4            15                       NaN
# 1  TRAIN_000001      8            15                     740.0
# 2  TRAIN_000002      9             6                    1610.0
#
#    Estimated_Arrival_Time  Cancelled  Diverted Origin_Airport  \
# 0                     NaN          0         0            OKC
# 1                  1024.0          0         0            ORD
# 2                  1805.0          0         0            CLT
#
#    Origin_Airport_ID    Origin_State Destination_Airport  \
# 0              13851        Oklahoma                 HOU
# 1              13930        Illinois                 SLC
# 2              11057  North Carolina                 LGA
#
#    Destination_Airport_ID Destination_State  Distance                 Airline  \
# 0                   12191             Texas     419.0  Southwest Airlines Co.
# 1                   14869              Utah    1250.0   SkyWest Airlines Inc.
# 2                   12953          New York     544.0  American Airlines Inc.
#
#   Carrier_Code(IATA)  Carrier_ID(DOT) Tail_Number Delay
# 0                 WN          19393.0      N7858A   NaN
# 1                 UA          20304.0      N125SY   NaN
# 2                 AA          19805.0      N103US   NaN

# %%
train_df.isna().sum()
# Out:
# ID                               0
# Month                            0
# Day_of_Month                     0
# Estimated_Departure_Time    109019
# Estimated_Arrival_Time      109040
# Cancelled                        0
# Diverted                         0
# Origin_Airport                   0
# Origin_Airport_ID                0
# Origin_State                109015
# Destination_Airport              0
# Destination_Airport_ID           0
# Destination_State           109079
# Distance                         0
# Airline                     108920
# Carrier_Code(IATA)          108990
# Carrier_ID(DOT)             108997
# Tail_Number                      0
# Delay                       744999
# dtype: int64

# %%
train_df[train_df['Estimated_Arrival_Time'].isna() & train_df['Estimated_Departure_Time'].isna()] #출발예정시간과 도착예정시간 둘다 존재하지 않는 데이터가 11688개.
#출발예정시간 109019개와 도착예정시간109040개가 데이터가 존재하지 않는데 10만개의 데이터중 약 만개 정도만 출발,도착 예정시간 둘다 존재 하지 않음
# Out:
#                   ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 0       TRAIN_000000      4            15                       NaN
# 109     TRAIN_000109      3            29                       NaN
# 277     TRAIN_000277      8             9                       NaN
# 435     TRAIN_000435      9            12                       NaN
# 437     TRAIN_000437      7            12                       NaN
# ...              ...    ...           ...                       ...
# 999771  TRAIN_999771      7            10                       NaN
# 999777  TRAIN_999777      9            27                       NaN
# 999815  TRAIN_999815     12             1                       NaN
# 999911  TRAIN_999911      7            14                       NaN
# 999967  TRAIN_999967     12            30                       NaN
#
#         Estimated_Arrival_Time  Cancelled  Diverted Origin_Airport  \
# 0                          NaN          0         0            OKC
# 109                        NaN          0         0            PDX
# 277                        NaN          0         0            MKE
# 435                        NaN          0         0            OAK
# 437                        NaN          0         0            HOU
# ...                        ...        ...       ...            ...
# 999771                     NaN          0         0            FLL
# 999777                     NaN          0         0            STS
# 999815                     NaN          0         0            SEA
# 999911                     NaN          0         0            HOU
# 999967                     NaN          0         0            BNA
#
#         Origin_Airport_ID Origin_State Destination_Airport  \
# 0                   13851     Oklahoma                 HOU
# 109                 14057       Oregon                 DEN
# 277                 13342    Wisconsin                 IAH
# 435                 13796   California                 ORD
# 437                 12191        Texas                 MSY
# ...                   ...          ...                 ...
# 999771              11697      Florida                 ORD
# 999777              15023   California                 SEA
# 999815              14747   Washington                 BOI
# 999911              12191        Texas                 DEN
# 999967              10693    Tennessee                 ORD
#
#         Destination_Airport_ID Destination_State  Distance  \
# 0                        12191             Texas     419.0
# 109                      11292          Colorado     991.0
# 277                      12266             Texas     984.0
# 435                      13930          Illinois    1836.0
# 437                      13495               NaN     302.0
# ...                        ...               ...       ...
# 999771                   13930          Illinois    1182.0
# 999777                   14747        Washington     618.0
# 999815                   10713             Idaho     399.0
# 999911                   11292          Colorado     883.0
# 999967                   13930          Illinois     409.0
#
#                        Airline Carrier_Code(IATA)  Carrier_ID(DOT)  \
# 0       Southwest Airlines Co.                 WN          19393.0
# 109     Southwest Airlines Co.                 WN          19393.0
# 277         Mesa Airlines Inc.                 UA          20378.0
# 435           Spirit Air Lines                 NK          20416.0
# 437     Southwest Airlines Co.                 WN          19393.0
# ...                        ...                ...              ...
# 999771         JetBlue Airways                 B6              NaN
# 999777   SkyWest Airlines Inc.                 AS          20304.0
# 999815                     NaN                 AS          19687.0
# 999911  Southwest Airlines Co.                 WN          19393.0
# 999967                     NaN                 UA          20304.0
#
#        Tail_Number    Delay
# 0           N7858A      NaN
# 109         N499WN      NaN
# 277         N88335      NaN
# 435         N618NK      NaN
# 437         N265WN      NaN
# ...            ...      ...
# 999771      N529JB      NaN
# 999777      N403SY  Delayed
# 999815      N401QX      NaN
# 999911      N935WN      NaN
# 999967      N127SY      NaN
#
# [11688 rows x 19 columns]

# %%
train_df.nunique() 
#Cancelled와 Diverted 데이터는 모든 데이터가 0으로 존재 --> drop 
#Origin_Airport와 Origin_Airpirt_ID는 동일한 정보를 나타내므로 둘 중 하나를 drop
#Destination_Airport와 Destination_Airport_ID는 동일한 정보를 나타내므로 둘 중 하나 drop
# Out:
# ID                          1000000
# Month                            12
# Day_of_Month                     31
# Estimated_Departure_Time       1365
# Estimated_Arrival_Time         1428
# Cancelled                         1
# Diverted                          1
# Origin_Airport                  374
# Origin_Airport_ID               374
# Origin_State                     52
# Destination_Airport             375
# Destination_Airport_ID          375
# Destination_State                52
# Distance                       1597
# Airline                          28
# Carrier_Code(IATA)               11
# Carrier_ID(DOT)                  28
# Tail_Number                    6430
# Delay                             2
# dtype: int64

# %%
train_df.drop(['Cancelled','Diverted'], axis=1, inplace= True) #Cancelled와 Diverted 데이터는 모든 데이터가 0으로 존재 --> drop

# %%
#Origin_Airport와 Origin_Airpirt_ID는 동일한 정보를 나타내므로 둘 중 하나를 drop
train_df.drop('Origin_Airport', axis=1, inplace= True)

# %%
#Destination_Airport와 Destination_Airport_ID는 동일한 정보를 나타내므로 둘 중 하나 drop
train_df.drop('Destination_Airport', axis =1, inplace= True)

# %%
train_df.isna().sum()
# Out:
# ID                               0
# Month                            0
# Day_of_Month                     0
# Estimated_Departure_Time    109019
# Estimated_Arrival_Time      109040
# Origin_Airport_ID                0
# Origin_State                109015
# Destination_Airport_ID           0
# Destination_State           109079
# Distance                         0
# Airline                     108920
# Carrier_Code(IATA)          108990
# Carrier_ID(DOT)             108997
# Tail_Number                      0
# Delay                       744999
# dtype: int64

# %%
train_df.nunique()
# Out:
# ID                          1000000
# Month                            12
# Day_of_Month                     31
# Estimated_Departure_Time       1365
# Estimated_Arrival_Time         1428
# Origin_Airport_ID               374
# Origin_State                     52
# Destination_Airport_ID          375
# Destination_State                52
# Distance                       1597
# Airline                          28
# Carrier_Code(IATA)               11
# Carrier_ID(DOT)                  28
# Tail_Number                    6430
# Delay                             2
# dtype: int64

# %%
train_df[train_df['Origin_State'].isna() & train_df['Destination_State'].isna()] #출발주와 도착주 둘다 데이터가 존재하지 않는 개수 11996개
# Out:
#                   ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 18      TRAIN_000018      8            11                    1215.0
# 101     TRAIN_000101      2            23                    1515.0
# 203     TRAIN_000203      2            23                     940.0
# 206     TRAIN_000206      2            26                       NaN
# 594     TRAIN_000594      2            26                     920.0
# ...              ...    ...           ...                       ...
# 999215  TRAIN_999215      2            19                    2241.0
# 999238  TRAIN_999238     10            26                     706.0
# 999698  TRAIN_999698     10             6                    1932.0
# 999763  TRAIN_999763      8            14                    1009.0
# 999995  TRAIN_999995      9            18                     936.0
#
#         Estimated_Arrival_Time  Origin_Airport_ID Origin_State  \
# 18                      1258.0              11146          NaN
# 101                     1700.0              14783          NaN
# 203                     1806.0              14771          NaN
# 206                     2344.0              12264          NaN
# 594                      950.0              11066          NaN
# ...                        ...                ...          ...
# 999215                  2348.0              13487          NaN
# 999238                   904.0              10693          NaN
# 999698                     NaN              10821          NaN
# 999763                  1143.0              11278          NaN
# 999995                  1243.0              13930          NaN
#
#         Destination_Airport_ID Destination_State  Distance  \
# 18                       13930               NaN     416.0
# 101                      13930               NaN     438.0
# 203                      11618               NaN    2565.0
# 206                      10529               NaN     326.0
# 594                      15016               NaN     409.0
# ...                        ...               ...       ...
# 999215                   11337               NaN     144.0
# 999238                   13930               NaN     409.0
# 999698                   10721               NaN     369.0
# 999763                   13296               NaN     406.0
# 999995                   14100               NaN     678.0
#
#                             Airline Carrier_Code(IATA)  Carrier_ID(DOT)  \
# 18                              NaN                NaN          20046.0
# 101     Air Wisconsin Airlines Corp                NaN          20046.0
# 203                  Virgin America                 VX          21171.0
# 206              Mesa Airlines Inc.                 UA          20378.0
# 594          Southwest Airlines Co.                 WN          19393.0
# ...                             ...                ...              ...
# 999215        SkyWest Airlines Inc.                 DL          20304.0
# 999238                          NaN                 AA          19805.0
# 999698             Spirit Air Lines                 NK          20416.0
# 999763            Republic Airlines                NaN          20452.0
# 999995        United Air Lines Inc.                 UA          19977.0
#
#        Tail_Number Delay
# 18          N440AW   NaN
# 101         N440AW   NaN
# 203         N633VA   NaN
# 206         N522LR   NaN
# 594         N916WN   NaN
# ...            ...   ...
# 999215      N603SK   NaN
# 999238      N908AN   NaN
# 999698      N614NK   NaN
# 999763      N428YX   NaN
# 999995      N477UA   NaN
#
# [11996 rows x 15 columns]

# %%
train_df[train_df['Airline'].isna() & train_df['Carrier_Code(IATA)'].isna() & train_df['Carrier_ID(DOT)']] #
# Out:
#                   ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 18      TRAIN_000018      8            11                    1215.0
# 112     TRAIN_000112      2            21                    2020.0
# 243     TRAIN_000243      4            21                    1350.0
# 266     TRAIN_000266      2             5                    1155.0
# 373     TRAIN_000373      4            29                       NaN
# ...              ...    ...           ...                       ...
# 999400  TRAIN_999400      3            18                     945.0
# 999585  TRAIN_999585      4            30                     816.0
# 999688  TRAIN_999688      3            20                     715.0
# 999791  TRAIN_999791      9             8                    1305.0
# 999919  TRAIN_999919      5            13                    1030.0
#
#         Estimated_Arrival_Time  Origin_Airport_ID   Origin_State  \
# 18                      1258.0              11146            NaN
# 112                     2347.0              13487      Minnesota
# 243                     1455.0              12954     California
# 266                     1330.0              10721  Massachusetts
# 373                     1630.0              14107        Arizona
# ...                        ...                ...            ...
# 999400                  1215.0              10693      Tennessee
# 999585                   934.0              10397        Georgia
# 999688                   815.0              10800     California
# 999791                  1605.0              11292       Colorado
# 999919                  1340.0              13930       Illinois
#
#         Destination_Airport_ID Destination_State  Distance Airline  \
# 18                       13930               NaN     416.0     NaN
# 112                      11278          Virginia     931.0     NaN
# 243                      12889            Nevada     231.0     NaN
# 266                      11618        New Jersey     200.0     NaN
# 373                      13198          Missouri    1044.0     NaN
# ...                        ...               ...       ...     ...
# 999400                   11042              Ohio     448.0     NaN
# 999585                   11641    North Carolina     331.0     NaN
# 999688                   12889            Nevada     223.0     NaN
# 999791                   11259             Texas     651.0     NaN
# 999919                   12953          New York     733.0     NaN
#
#        Carrier_Code(IATA)  Carrier_ID(DOT) Tail_Number        Delay
# 18                    NaN          20046.0      N440AW          NaN
# 112                   NaN          19790.0      N324US  Not_Delayed
# 243                   NaN          19393.0      N462WN          NaN
# 266                   NaN          19977.0      N69835  Not_Delayed
# 373                   NaN          19393.0      N7719A          NaN
# ...                   ...              ...         ...          ...
# 999400                NaN          19393.0      N7812G          NaN
# 999585                NaN          20363.0      N8694A          NaN
# 999688                NaN          19393.0      N423WN          NaN
# 999791                NaN          19393.0      N218WN  Not_Delayed
# 999919                NaN          19805.0      N959NN          NaN
#
# [10591 rows x 15 columns]

# %%
train_df[train_df['Carrier_Code(IATA)']== 'UA']
# Out:
#                   ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 1       TRAIN_000001      8            15                     740.0
# 3       TRAIN_000003      7            10                     905.0
# 4       TRAIN_000004      1            11                     900.0
# 5       TRAIN_000005      4            13                    1545.0
# 6       TRAIN_000006      1            20                    1742.0
# ...              ...    ...           ...                       ...
# 999972  TRAIN_999972      5            26                    1130.0
# 999984  TRAIN_999984      8             4                     834.0
# 999989  TRAIN_999989      1            12                    1717.0
# 999992  TRAIN_999992     12            30                    1307.0
# 999995  TRAIN_999995      9            18                     936.0
#
#         Estimated_Arrival_Time  Origin_Airport_ID Origin_State  \
# 1                       1024.0              13930     Illinois
# 3                       1735.0              12892   California
# 4                       1019.0              14771   California
# 5                          NaN              11618          NaN
# 6                       1903.0              11618   New Jersey
# ...                        ...                ...          ...
# 999972                  1333.0              10599      Alabama
# 999984                  1010.0              14869         Utah
# 999989                  2019.0              11618   New Jersey
# 999992                  1707.0              12441      Wyoming
# 999995                  1243.0              13930          NaN
#
#         Destination_Airport_ID Destination_State  Distance  \
# 1                        14869              Utah    1250.0
# 3                        11618        New Jersey    2454.0
# 4                        10157        California     250.0
# 5                        11278          Virginia     199.0
# 6                        10721     Massachusetts     200.0
# ...                        ...               ...       ...
# 999972                   12266             Texas     562.0
# 999984                   11292          Colorado     391.0
# 999989                   14027           Florida    1023.0
# 999992                   13930          Illinois    1162.0
# 999995                   14100               NaN     678.0
#
#                          Airline Carrier_Code(IATA)  Carrier_ID(DOT)  \
# 1          SkyWest Airlines Inc.                 UA          20304.0
# 3          United Air Lines Inc.                 UA              NaN
# 4          SkyWest Airlines Inc.                 UA          20304.0
# 5              Republic Airlines                 UA          20452.0
# 6          United Air Lines Inc.                 UA              NaN
# ...                          ...                ...              ...
# 999972  ExpressJet Airlines Inc.                 UA          20366.0
# 999984     SkyWest Airlines Inc.                 UA          20304.0
# 999989     United Air Lines Inc.                 UA          19977.0
# 999992     United Air Lines Inc.                 UA          19977.0
# 999995     United Air Lines Inc.                 UA          19977.0
#
#        Tail_Number        Delay
# 1           N125SY          NaN
# 3           N595UA          NaN
# 4           N161SY          NaN
# 5           N657RW  Not_Delayed
# 6           N66825  Not_Delayed
# ...            ...          ...
# 999972      N11547          NaN
# 999984      N203SY          NaN
# 999989      N18223          NaN
# 999992      N17719  Not_Delayed
# 999995      N477UA          NaN
#
# [206211 rows x 15 columns]

# %%
train_df[train_df['Airline']=='United Air Lines Inc.'].head()	 # airline과 carrier_id는 항공사와 항공사 id를 표현한 것으로 결측치를 항공사와 항공사에 맞는 id를 넣은 후 -- 둘중 하나  drop
# Out:
#               ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 3   TRAIN_000003      7            10                     905.0
# 6   TRAIN_000006      1            20                    1742.0
# 31  TRAIN_000031      8            19                     600.0
# 43  TRAIN_000043      9            30                    1325.0
# 54  TRAIN_000054      3            12                    1800.0
#
#     Estimated_Arrival_Time  Origin_Airport_ID Origin_State  \
# 3                   1735.0              12892   California
# 6                   1903.0              11618   New Jersey
# 31                   847.0              12889          NaN
# 43                  1506.0              14679   California
# 54                  2109.0              11618   New Jersey
#
#     Destination_Airport_ID Destination_State  Distance                Airline  \
# 3                    11618        New Jersey    2454.0  United Air Lines Inc.
# 6                    10721     Massachusetts     200.0  United Air Lines Inc.
# 31                   11292          Colorado     628.0  United Air Lines Inc.
# 43                   14771        California     447.0  United Air Lines Inc.
# 54                   12892        California    2454.0  United Air Lines Inc.
#
#    Carrier_Code(IATA)  Carrier_ID(DOT) Tail_Number        Delay
# 3                  UA              NaN      N595UA          NaN
# 6                  UA              NaN      N66825  Not_Delayed
# 31                 UA          19977.0      N17245          NaN
# 43                 UA              NaN      N471UA  Not_Delayed
# 54                 UA              NaN      N14107          NaN

# %%
train_df.isna().sum() # 항공사, 항공사 id, 항공사 코드는 서로 연관이 있기 때문에 결측치를 채워 넣을 수 있음 ///
#출발예정시간, 도착 예정시간 -- 이거를  
#도착주 , 출발주  --
# Out:
# ID                               0
# Month                            0
# Day_of_Month                     0
# Estimated_Departure_Time    109019
# Estimated_Arrival_Time      109040
# Origin_Airport_ID                0
# Origin_State                109015
# Destination_Airport_ID           0
# Destination_State           109079
# Distance                         0
# Airline                     108920
# Carrier_Code(IATA)          108990
# Carrier_ID(DOT)             108997
# Tail_Number                      0
# Delay                       744999
# dtype: int64

# %%
train_df.head(3)
# Out:
#              ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 0  TRAIN_000000      4            15                       NaN
# 1  TRAIN_000001      8            15                     740.0
# 2  TRAIN_000002      9             6                    1610.0
#
#    Estimated_Arrival_Time  Origin_Airport_ID    Origin_State  \
# 0                     NaN              13851        Oklahoma
# 1                  1024.0              13930        Illinois
# 2                  1805.0              11057  North Carolina
#
#    Destination_Airport_ID Destination_State  Distance                 Airline  \
# 0                   12191             Texas     419.0  Southwest Airlines Co.
# 1                   14869              Utah    1250.0   SkyWest Airlines Inc.
# 2                   12953          New York     544.0  American Airlines Inc.
#
#   Carrier_Code(IATA)  Carrier_ID(DOT) Tail_Number Delay
# 0                 WN          19393.0      N7858A   NaN
# 1                 UA          20304.0      N125SY   NaN
# 2                 AA          19805.0      N103US   NaN

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   ID                        1000000 non-null  object
#  1   Month                     1000000 non-null  int64
#  2   Day_of_Month              1000000 non-null  int64
#  3   Estimated_Departure_Time  890981 non-null   float64
#  4   Estimated_Arrival_Time    890960 non-null   float64
#  5   Origin_Airport_ID         1000000 non-null  int64
#  6   Origin_State              890985 non-null   object
#  7   Destination_Airport_ID    1000000 non-null  int64
#  8   Destination_State         890921 non-null   object
#  9   Distance                  1000000 non-null  float64
#  10  Airline                   891080 non-null   object
#  11  Carrier_Code(IATA)        891010 non-null   object
#  12  Carrier_ID(DOT)           891003 non-null   float64
#  13  Tail_Number               1000000 non-null  object
#  14  Delay                     255001 non-null   object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 114.4+ MB

# %%
train_df[train_df['Delay']=='Delayed']
# Out:
#                   ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 10      TRAIN_000010      8            13                    1730.0
# 55      TRAIN_000055      8            18                    1700.0
# 95      TRAIN_000095      3            14                    1905.0
# 118     TRAIN_000118      4            11                    1935.0
# 162     TRAIN_000162     12            16                    2040.0
# ...              ...    ...           ...                       ...
# 999816  TRAIN_999816     11             6                    2115.0
# 999843  TRAIN_999843      6            13                    1749.0
# 999955  TRAIN_999955      4            12                    1310.0
# 999963  TRAIN_999963      5             2                    1759.0
# 999969  TRAIN_999969     10            10                     940.0
#
#         Estimated_Arrival_Time  Origin_Airport_ID Origin_State  \
# 10                      1844.0              11278     Virginia
# 55                      1900.0              12191        Texas
# 95                      2159.0              14027          NaN
# 118                     2115.0              10397      Georgia
# 162                     2249.0              14747   Washington
# ...                        ...                ...          ...
# 999816                  2348.0              13930     Illinois
# 999843                  1850.0              13342    Wisconsin
# 999955                  1356.0              14747   Washington
# 999963                  1926.0              12953     New York
# 999969                  1056.0              13256        Texas
#
#         Destination_Airport_ID Destination_State  Distance  \
# 10                       14122      Pennsylvania     204.0
# 55                       10693         Tennessee     670.0
# 95                       12953          New York    1035.0
# 118                      13487         Minnesota     907.0
# 162                      14831        California     696.0
# ...                        ...               ...       ...
# 999816                   11076          Michigan     360.0
# 999843                   13930          Illinois      67.0
# 999955                   14057            Oregon     129.0
# 999963                   11278          Virginia     214.0
# 999969                   12266             Texas     316.0
#
#                        Airline Carrier_Code(IATA)  Carrier_ID(DOT)  \
# 10           Republic Airlines                 AA              NaN
# 55      Southwest Airlines Co.                NaN          19393.0
# 95             JetBlue Airways                 B6          20409.0
# 118       Delta Air Lines Inc.                 DL          19790.0
# 162       Alaska Airlines Inc.                 AS          19930.0
# ...                        ...                ...              ...
# 999816   SkyWest Airlines Inc.                 UA          20304.0
# 999843   Trans States Airlines                 UA          20237.0
# 999955             Horizon Air                 AS          19687.0
# 999963                     NaN                 DL          20452.0
# 999969      Mesa Airlines Inc.                NaN          20378.0
#
#        Tail_Number    Delay
# 10          N119HQ  Delayed
# 55          N8658A  Delayed
# 95          N337JB  Delayed
# 118         N912DU  Delayed
# 162         N551AS  Delayed
# ...            ...      ...
# 999816      N964SW  Delayed
# 999843      N12136  Delayed
# 999955      N432QX  Delayed
# 999963      N871RW  Delayed
# 999969      N89321  Delayed
#
# [45000 rows x 15 columns]

# %%
#딜레이 된 데이터와 딜레이 되지 않은 데이터 , 딜레이 여부가 존재하지 않는 데이터 이렇게 3종류가 있다고 할 때 
# 각각 돌려서

# %% [markdown]
# 그냥 생각해본거 --
# 항공사 별로 -- 이게 비행기 id같은게 있으면 (이게 tail_number인가)
#
# 1. 이게 딜레이 여부가 거리와 관련이 있다고 생각되는데 항공사(비행기)별로 같은 거리라 하더라도 어떤 항공사 비행기는 빨리 가고 어떤 항공사 비행기는 느리게 갈 수 있지 않을까 -- 싶어서
# 2. 거리와 항공사(비행기)이게 관련이 있다면 // 우선 출발예정시간과 도착예정시간으로 비행시간을 알수 있고 --> train_df에 비행시간 추가하기 : 도착예정시간- 출발예정시간
# 3. 데이터 프레임에 비행시간을 추가한 뒤 -- 20만개 정도가 출발 혹은 도착예정 시간 데이터가 존재하지 않음. > 거리와 비행시간이 항공사와 관계없이 비례한다면 --> 거리 데이터는 결측치가 존재하지 않으니 --> 모든 데이터에 비행시간을 추가해줄 수 있음 --> 그렇다면 출발예정시간이나 도착예정시간 둘 중 한 데이터만 존재한다면 비행시간을 알기 때문에 다른 시간을 알수 있으므로 --> 출발, 도착예정시간 둘다 없는 데이터를 제외한 대부분의 데이터의 결측치를 보완할수 있음
# 4. 문제는 거리와 비행시간이 항공사에 따라 달라질 때 -- -이럴때는 어떻게 해야할지--- 이건 회의때 말해보고
# 5. 그냥 거리에 따라 비행시간이 비례한다고 가정하면 만개 정도의 데이터를 제외하고는 대부분의 결측치가 채워짐 --
#
# 6. 출발주, 도착주  --- > 출발 공항 id, 도착 공항 id와 관련이 있긴 한데 -- 만약 texas라 가정하면 위에 < train_df[train_df['Delay']=='Delayed'] > 에서만 해도 25개나 존재 -- 이걸 그냥 삭제 해버리기에는 출발공항과 도착 공항이 필요할거 같은데 --

# %% [markdown]
# #####
# 1. 딜레이 여부와 거리가 관련이 있다고 가정--
# 2. 거리와 항공사(비행기)가 관련이 있는지 없는지 -- 관련이 있다면 같은 거리를 비행한다고 하더라도 항공사 별로 비행시간의 차이가 있지 않을까
# 3. 거리와 항공사가 관련이 없다면 -- 거리와 비행시간은 비례한다고 가정
# 4. 출발예정시간과 도착예정시간으로 비행예정시간을 알아낼 수 있고 이를 데이터프레임에 비행예정시간 컬럼을 새로 추가
# 5. 거리와 비행시간이 비례한다고 가정했으므로 거리정보는 모든 데이터가 존재하므로 모든 데이터에 비행시간을 추가할수 있음 -- 문제점) 그럼 거리와 비행시간이 비례하면 비행시간을 넣어야 하는 이유가 있을까  --
# 6. 비행시간을 알기 때문에 출발시간을 알면 도착시간을 알수 있고, 도착시간을 알면 출발시간을 알수 있음  -- 출발시간과 도착시간 둘다 모르는 약 만개의 데이터만 제외하고 대부분의 결측치를 채울 수 있음   -- ) 비행시간으로 출발,도착시간을 채워넣기 위함?
#
# 7. 출발주, 도착주  --> 출발공항id와 도착공항id와 관련은 있으나 그냥 drop하기에는 필요한 데이터지 않을까 싶은데 -- > 출발주가 texas라 가정하면 그에 맞는 출발공항id가 25개나 존재 --

# %%
train_df[train_df['Origin_State']=='Texas'].nunique()
# Out:
# ID                          89074
# Month                          12
# Day_of_Month                   31
# Estimated_Departure_Time     1097
# Estimated_Arrival_Time       1187
# Origin_Airport_ID              25
# Origin_State                    1
# Destination_Airport_ID        194
# Destination_State              48
# Distance                      463
# Airline                        21
# Carrier_Code(IATA)             10
# Carrier_ID(DOT)                21
# Tail_Number                  4883
# Delay                           2
# dtype: int64

# %% [markdown]
# 1. 거리별 비행시간 계산
# 2. 회귀
# 3. 선형

# %%
train_df
# Out:
#                   ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 0       TRAIN_000000      4            15                       NaN
# 1       TRAIN_000001      8            15                     740.0
# 2       TRAIN_000002      9             6                    1610.0
# 3       TRAIN_000003      7            10                     905.0
# 4       TRAIN_000004      1            11                     900.0
# ...              ...    ...           ...                       ...
# 999995  TRAIN_999995      9            18                     936.0
# 999996  TRAIN_999996      5            30                     920.0
# 999997  TRAIN_999997      6            28                     800.0
# 999998  TRAIN_999998      9            27                    1613.0
# 999999  TRAIN_999999      3            26                    1800.0
#
#         Estimated_Arrival_Time  Origin_Airport_ID    Origin_State  \
# 0                          NaN              13851        Oklahoma
# 1                       1024.0              13930        Illinois
# 2                       1805.0              11057  North Carolina
# 3                       1735.0              12892      California
# 4                       1019.0              14771      California
# ...                        ...                ...             ...
# 999995                  1243.0              13930             NaN
# 999996                  1028.0              11637             NaN
# 999997                  1340.0              13796             NaN
# 999998                  1824.0              10693       Tennessee
# 999999                  2056.0              14635         Florida
#
#         Destination_Airport_ID Destination_State  Distance  \
# 0                        12191             Texas     419.0
# 1                        14869              Utah    1250.0
# 2                        12953          New York     544.0
# 3                        11618        New Jersey    2454.0
# 4                        10157        California     250.0
# ...                        ...               ...       ...
# 999995                   14100               NaN     678.0
# 999996                   13487         Minnesota     223.0
# 999997                   12191             Texas    1642.0
# 999998                   10397               NaN     214.0
# 999999                   11433          Michigan    1084.0
#
#                        Airline Carrier_Code(IATA)  Carrier_ID(DOT)  \
# 0       Southwest Airlines Co.                 WN          19393.0
# 1        SkyWest Airlines Inc.                 UA          20304.0
# 2       American Airlines Inc.                 AA          19805.0
# 3        United Air Lines Inc.                 UA              NaN
# 4        SkyWest Airlines Inc.                 UA          20304.0
# ...                        ...                ...              ...
# 999995   United Air Lines Inc.                 UA          19977.0
# 999996   SkyWest Airlines Inc.                 DL              NaN
# 999997  Southwest Airlines Co.                 WN          19393.0
# 999998    Delta Air Lines Inc.                 DL          19790.0
# 999999                     NaN                 DL          19790.0
#
#        Tail_Number Delay
# 0           N7858A   NaN
# 1           N125SY   NaN
# 2           N103US   NaN
# 3           N595UA   NaN
# 4           N161SY   NaN
# ...            ...   ...
# 999995      N477UA   NaN
# 999996      N439SW   NaN
# 999997      N230WN   NaN
# 999998      N968DL   NaN
# 999999      N695DL   NaN
#
# [1000000 rows x 15 columns]

# %% [markdown]
# 여기서부터

# %%
s = train_df[train_df['Estimated_Departure_Time'].isna() & ~train_df['Estimated_Arrival_Time'].isna()]
t = train_df[~train_df['Estimated_Departure_Time'].isna() & train_df['Estimated_Arrival_Time'].isna()]
test_s = test_df[test_df['Estimated_Departure_Time'].isna() & ~test_df['Estimated_Arrival_Time'].isna()]
test_t = test_df[~test_df['Estimated_Departure_Time'].isna() & test_df['Estimated_Arrival_Time'].isna()]

# %%
test_df[test_df['Estimated_Departure_Time'].isna() & test_df['Estimated_Arrival_Time'].isna()].isna().sum()
# Out:
# ID                              0
# Month                           0
# Day_of_Month                    0
# Estimated_Departure_Time    11928
# Estimated_Arrival_Time      11928
# Cancelled                       0
# Diverted                        0
# Origin_Airport                  0
# Origin_Airport_ID               0
# Origin_State                 1239
# Destination_Airport             0
# Destination_Airport_ID          0
# Destination_State            1209
# Distance                        0
# Airline                      1286
# Carrier_Code(IATA)           1331
# Carrier_ID(DOT)              1308
# Tail_Number                     0
# dtype: int64

# %%
mean_time = 232
train_df['Estimated_Departure_Time'][train_df['Estimated_Departure_Time'].isna() & ~train_df['Estimated_Arrival_Time'].isna()] = s['Estimated_Arrival_Time'] - mean_time
train_df['Estimated_Arrival_Time'][~train_df['Estimated_Departure_Time'].isna() & train_df['Estimated_Arrival_Time'].isna()] = t['Estimated_Departure_Time'] + mean_time
