# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import math
import json
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from IPython.display import Image
import seaborn as sns
import missingno as msnco

# %%
train_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dacon/train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dacon/test.csv')

# %%
sample_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dacon/sample_submission.csv')

# %%
train_df
# Out:
#                   ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 0       TRAIN_000000      4            15                       NaN
# 1       TRAIN_000001      8            15                     740.0
# 2       TRAIN_000002      9             6                    1610.0
# 3       TRAIN_000003      7            10                     905.0
# 4       TRAIN_000004      1            11                     900.0
# ...              ...    ...           ...                       ...
# 999995  TRAIN_999995      9            18                     936.0
# 999996  TRAIN_999996      5            30                     920.0
# 999997  TRAIN_999997      6            28                     800.0
# 999998  TRAIN_999998      9            27                    1613.0
# 999999  TRAIN_999999      3            26                    1800.0
#
#         Estimated_Arrival_Time  Cancelled  Diverted Origin_Airport  \
# 0                          NaN          0         0            OKC
# 1                       1024.0          0         0            ORD
# 2                       1805.0          0         0            CLT
# 3                       1735.0          0         0            LAX
# 4                       1019.0          0         0            SFO
# ...                        ...        ...       ...            ...
# 999995                  1243.0          0         0            ORD
# 999996                  1028.0          0         0            FAR
# 999997                  1340.0          0         0            OAK
# 999998                  1824.0          0         0            BNA
# 999999                  2056.0          0         0            RSW
#
#         Origin_Airport_ID    Origin_State Destination_Airport  \
# 0                   13851        Oklahoma                 HOU
# 1                   13930        Illinois                 SLC
# 2                   11057  North Carolina                 LGA
# 3                   12892      California                 EWR
# 4                   14771      California                 ACV
# ...                   ...             ...                 ...
# 999995              13930             NaN                 PHL
# 999996              11637             NaN                 MSP
# 999997              13796             NaN                 HOU
# 999998              10693       Tennessee                 ATL
# 999999              14635         Florida                 DTW
#
#         Destination_Airport_ID Destination_State  Distance  \
# 0                        12191             Texas     419.0
# 1                        14869              Utah    1250.0
# 2                        12953          New York     544.0
# 3                        11618        New Jersey    2454.0
# 4                        10157        California     250.0
# ...                        ...               ...       ...
# 999995                   14100               NaN     678.0
# 999996                   13487         Minnesota     223.0
# 999997                   12191             Texas    1642.0
# 999998                   10397               NaN     214.0
# 999999                   11433          Michigan    1084.0
#
#                        Airline Carrier_Code(IATA)  Carrier_ID(DOT)  \
# 0       Southwest Airlines Co.                 WN          19393.0
# 1        SkyWest Airlines Inc.                 UA          20304.0
# 2       American Airlines Inc.                 AA          19805.0
# 3        United Air Lines Inc.                 UA              NaN
# 4        SkyWest Airlines Inc.                 UA          20304.0
# ...                        ...                ...              ...
# 999995   United Air Lines Inc.                 UA          19977.0
# 999996   SkyWest Airlines Inc.                 DL              NaN
# 999997  Southwest Airlines Co.                 WN          19393.0
# 999998    Delta Air Lines Inc.                 DL          19790.0
# 999999                     NaN                 DL          19790.0
#
#        Tail_Number Delay
# 0           N7858A   NaN
# 1           N125SY   NaN
# 2           N103US   NaN
# 3           N595UA   NaN
# 4           N161SY   NaN
# ...            ...   ...
# 999995      N477UA   NaN
# 999996      N439SW   NaN
# 999997      N230WN   NaN
# 999998      N968DL   NaN
# 999999      N695DL   NaN
#
# [1000000 rows x 19 columns]

# %%
train_df.nunique()
# Out:
# ID                          1000000
# Month                            12
# Day_of_Month                     31
# Estimated_Departure_Time       1365
# Estimated_Arrival_Time         1428
# Cancelled                         1
# Diverted                          1
# Origin_Airport                  374
# Origin_Airport_ID               374
# Origin_State                     52
# Destination_Airport             375
# Destination_Airport_ID          375
# Destination_State                52
# Distance                       1597
# Airline                          28
# Carrier_Code(IATA)               11
# Carrier_ID(DOT)                  28
# Tail_Number                    6430
# Delay                             2
# dtype: int64

# %%
train_df.drop(['Cancelled','Diverted'], axis=1, inplace= True) #Cancelled와 Diverted 데이터는 모든 데이터가 0으로 존재 --> drop

# %%
#Origin_Airport와 Origin_Airpirt_ID는 동일한 정보를 나타내므로 둘 중 하나를 drop
train_df.drop('Origin_Airport', axis=1, inplace= True)

# %%
#Destination_Airport와 Destination_Airport_ID는 동일한 정보를 나타내므로 둘 중 하나 drop
train_df.drop('Destination_Airport', axis =1, inplace= True)

# %%
train_df.isna().sum()
# Out:
# ID                               0
# Month                            0
# Day_of_Month                     0
# Estimated_Departure_Time    109019
# Estimated_Arrival_Time      109040
# Origin_Airport                   0
# Origin_Airport_ID                0
# Origin_State                109015
# Destination_Airport              0
# Destination_Airport_ID           0
# Destination_State           109079
# Distance                         0
# Airline                     108920
# Carrier_Code(IATA)          108990
# Carrier_ID(DOT)             108997
# Tail_Number                      0
# Delay                       744999
# dtype: int64

# %%
train_df.nunique() #airline과 carrier_ID(dot) 같은 정보
# Out:
# ID                          1000000
# Month                            12
# Day_of_Month                     31
# Estimated_Departure_Time       1365
# Estimated_Arrival_Time         1428
# Origin_Airport                  374
# Origin_Airport_ID               374
# Origin_State                     52
# Destination_Airport             375
# Destination_Airport_ID          375
# Destination_State                52
# Distance                       1597
# Airline                          28
# Carrier_Code(IATA)               11
# Carrier_ID(DOT)                  28
# Tail_Number                    6430
# Delay                             2
# dtype: int64

# %%
#delay 1, 0 으로 변환
dic = {'Not_Delayed' : 0, 'Delayed' : 1}
train_df['Delay'] = train_df['Delay'].map(dic) # delay float타입으로 변경

# %%
train_df.columns
# Out:
# Index(['ID', 'Month', 'Day_of_Month', 'Estimated_Departure_Time',
#        'Estimated_Arrival_Time', 'Origin_Airport_ID', 'Origin_State',
#        'Destination_Airport_ID', 'Destination_State', 'Distance', 'Airline',
#        'Carrier_Code(IATA)', 'Carrier_ID(DOT)', 'Tail_Number', 'Delay'],
#       dtype='object')

# %%
df = train_df[['ID','Estimated_Departure_Time','Estimated_Arrival_Time','Origin_State','Destination_State','Distance','Delay']]

# %%
df
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 0       TRAIN_000000                       NaN                     NaN
# 1       TRAIN_000001                     740.0                  1024.0
# 2       TRAIN_000002                    1610.0                  1805.0
# 3       TRAIN_000003                     905.0                  1735.0
# 4       TRAIN_000004                     900.0                  1019.0
# ...              ...                       ...                     ...
# 999995  TRAIN_999995                     936.0                  1243.0
# 999996  TRAIN_999996                     920.0                  1028.0
# 999997  TRAIN_999997                     800.0                  1340.0
# 999998  TRAIN_999998                    1613.0                  1824.0
# 999999  TRAIN_999999                    1800.0                  2056.0
#
#           Origin_State Destination_State  Distance  Delay
# 0             Oklahoma             Texas     419.0    NaN
# 1             Illinois              Utah    1250.0    NaN
# 2       North Carolina          New York     544.0    NaN
# 3           California        New Jersey    2454.0    NaN
# 4           California        California     250.0    NaN
# ...                ...               ...       ...    ...
# 999995             NaN               NaN     678.0    NaN
# 999996             NaN         Minnesota     223.0    NaN
# 999997             NaN             Texas    1642.0    NaN
# 999998       Tennessee               NaN     214.0    NaN
# 999999         Florida          Michigan    1084.0    NaN
#
# [1000000 rows x 7 columns]

# %% [markdown]
# #첫번째 비행시간 계산

# %%
train_df

# %%
train_df['flight_time'] = train_df['Estimated_Arrival_Time']- train_df['Estimated_Departure_Time']  #비행시간 컬럼 추가 
train_df['flight_time'] = train_df['flight_time'].apply(lambda x : x+2400 if x<0 else x)
train_df['flight_time'] = train_df['flight_time'].apply(lambda x : x+40 if x%100//10>=6 else x)

# %%
#첫번째 방법 -- 거리별 비행시간 계산
# import math

flight_mean = train_df['flight_time'].mean() #비행시간 평균
distance_mean =  train_df['Distance'].mean() #거리 평균
means = flight_mean/distance_mean

train_df['flight_time'] = train_df['flight_time'].fillna(round(train_df['Distance']*means))  #비행시간 결측치인 데이터에 거리별 비행시간 계산해서 넣기
# Out:
# 0.3175785343381852

# %%
#두번째 방법  -- 거리별 비행시간을 회귀 모델로 학습시키기 
#x 거리  y 비행시간

# %%
X_train = train_df['flight_time'].dropna()
idx = X_train.index

y_train = train_df.loc[idx]['flight_time']

X_train = X_train.values.reshape(-1,1) 
y_train = y_train.values.reshape(-1,1)

test_data = train_df[train_df['flight_time'].isna()] 
X_test = test_data['Distance']

X_test = X_test.values.reshape(-1,1)

# %%
#단순 선형 회귀모델

# 모델 임포트 
from sklearn.linear_model import LinearRegression

# 모델 인스턴스 생성
lin_reg = LinearRegression()

# 모델 피팅
lin_reg.fit(X_train,y_train)

# 모델 예측
y_pred = lin_reg.predict(X_test)
y_pred
# Out:
# array([[ 419.],
#        [ 199.],
#        [ 369.],
#        ...,
#        [ 646.],
#        [ 802.],
#        [1476.]])

# %%
#문제점 

# 시간을 빼서 구할 순 있음. 하지만 며칠이 걸렸는지가 알수 없어 애매.

# %% [markdown]
# 도착예정시간 - 출발예정시간 = 비행시간
# 문제점
# - 정확한 도착 예정 날짜가 나와있는게 아닌 시간만 나와있어서 비행시간 25시간과 1시간의 차이를 구분할 수 없음.
# - 출발시간과 도착시간이 같아 비행시간이 0으로 나오는 경우가 존재 --> 출발예정시간은 출발주의 시간을, 도착예정시간은 도착주의 시간을 기준으로 나와있어 시차가 존재하여 단순히 도착예정시간과 출발예정시간을 빼면 안됨. 시차 고려가 필요
#
# 해결방법
# - 출발주 A, 도착주가 B인 경우의 비행시간과  출발주B, 도착주A인 경우의 비행시간과  비교하여 각각 나온 비행시간을 빼고 2로 나누어 시차를 계산

# %% [markdown]
# # 두번째

# %%
train_df[train_df['Origin_State']=='Texas']
#텍사스 출발 캘리포니아 도착 2041  2210   거리 1379   / 1시간 30분

# %%
train_df[train_df['Origin_State']=='California'] 
#캘리포티아 출발 텍사스 도착 1150   1705  거리 1346  / 5시간 15분

# %%
train_df.nunique()
# Out:
# ID                          1000000
# Month                            12
# Day_of_Month                     31
# Estimated_Departure_Time       1365
# Estimated_Arrival_Time         1428
# Origin_Airport                  374
# Origin_Airport_ID               374
# Origin_State                     52
# Destination_Airport             375
# Destination_Airport_ID          375
# Destination_State                52
# Distance                       1597
# Airline                          28
# Carrier_Code(IATA)               11
# Carrier_ID(DOT)                  28
# Tail_Number                    6430
# Delay                             2
# dtype: int64

# %%
train_df
# Out:
#                   ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 0       TRAIN_000000      4            15                       NaN
# 1       TRAIN_000001      8            15                     740.0
# 2       TRAIN_000002      9             6                    1610.0
# 3       TRAIN_000003      7            10                     905.0
# 4       TRAIN_000004      1            11                     900.0
# ...              ...    ...           ...                       ...
# 999995  TRAIN_999995      9            18                     936.0
# 999996  TRAIN_999996      5            30                     920.0
# 999997  TRAIN_999997      6            28                     800.0
# 999998  TRAIN_999998      9            27                    1613.0
# 999999  TRAIN_999999      3            26                    1800.0
#
#         Estimated_Arrival_Time Origin_Airport  Origin_Airport_ID  \
# 0                          NaN            OKC              13851
# 1                       1024.0            ORD              13930
# 2                       1805.0            CLT              11057
# 3                       1735.0            LAX              12892
# 4                       1019.0            SFO              14771
# ...                        ...            ...                ...
# 999995                  1243.0            ORD              13930
# 999996                  1028.0            FAR              11637
# 999997                  1340.0            OAK              13796
# 999998                  1824.0            BNA              10693
# 999999                  2056.0            RSW              14635
#
#           Origin_State Destination_Airport  Destination_Airport_ID  \
# 0             Oklahoma                 HOU                   12191
# 1             Illinois                 SLC                   14869
# 2       North Carolina                 LGA                   12953
# 3           California                 EWR                   11618
# 4           California                 ACV                   10157
# ...                ...                 ...                     ...
# 999995             NaN                 PHL                   14100
# 999996             NaN                 MSP                   13487
# 999997             NaN                 HOU                   12191
# 999998       Tennessee                 ATL                   10397
# 999999         Florida                 DTW                   11433
#
#        Destination_State  Distance                 Airline Carrier_Code(IATA)  \
# 0                  Texas     419.0  Southwest Airlines Co.                 WN
# 1                   Utah    1250.0   SkyWest Airlines Inc.                 UA
# 2               New York     544.0  American Airlines Inc.                 AA
# 3             New Jersey    2454.0   United Air Lines Inc.                 UA
# 4             California     250.0   SkyWest Airlines Inc.                 UA
# ...                  ...       ...                     ...                ...
# 999995               NaN     678.0   United Air Lines Inc.                 UA
# 999996         Minnesota     223.0   SkyWest Airlines Inc.                 DL
# 999997             Texas    1642.0  Southwest Airlines Co.                 WN
# 999998               NaN     214.0    Delta Air Lines Inc.                 DL
# 999999          Michigan    1084.0                     NaN                 DL
#
#         Carrier_ID(DOT) Tail_Number Delay
# 0               19393.0      N7858A   NaN
# 1               20304.0      N125SY   NaN
# 2               19805.0      N103US   NaN
# 3                   NaN      N595UA   NaN
# 4               20304.0      N161SY   NaN
# ...                 ...         ...   ...
# 999995          19977.0      N477UA   NaN
# 999996              NaN      N439SW   NaN
# 999997          19393.0      N230WN   NaN
# 999998          19790.0      N968DL   NaN
# 999999          19790.0      N695DL   NaN
#
# [1000000 rows x 17 columns]

# %%
df = train_df[['ID','Estimated_Departure_Time','Estimated_Arrival_Time','Origin_State','Destination_State','Distance']]
df
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 0       TRAIN_000000                       NaN                     NaN
# 1       TRAIN_000001                     740.0                  1024.0
# 2       TRAIN_000002                    1610.0                  1805.0
# 3       TRAIN_000003                     905.0                  1735.0
# 4       TRAIN_000004                     900.0                  1019.0
# ...              ...                       ...                     ...
# 999995  TRAIN_999995                     936.0                  1243.0
# 999996  TRAIN_999996                     920.0                  1028.0
# 999997  TRAIN_999997                     800.0                  1340.0
# 999998  TRAIN_999998                    1613.0                  1824.0
# 999999  TRAIN_999999                    1800.0                  2056.0
#
#           Origin_State Destination_State  Distance
# 0             Oklahoma             Texas     419.0
# 1             Illinois              Utah    1250.0
# 2       North Carolina          New York     544.0
# 3           California        New Jersey    2454.0
# 4           California        California     250.0
# ...                ...               ...       ...
# 999995             NaN               NaN     678.0
# 999996             NaN         Minnesota     223.0
# 999997             NaN             Texas    1642.0
# 999998       Tennessee               NaN     214.0
# 999999         Florida          Michigan    1084.0
#
# [1000000 rows x 6 columns]

# %%
df['Origin_State'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0               Oklahoma
# 1               Illinois
# 2         North Carolina
# 3             California
# 4             California
#                ...
# 999995               NaN
# 999996               NaN
# 999997               NaN
# 999998         Tennessee
# 999999           Florida
# Name: Origin_State, Length: 1000000, dtype: object>

# %%
# for i in #origin_state.nuique  출발주 52개 리스트
    # for j in destination_state: 도착주 52개 리스트 
        # if df[(df['Origin_State']==i) & (df['Destination_State']==j)]
df = df.dropna(subset=['Origin_State','Destination_State'])

# %%
df  # 시차를 알아 / 출발시간이 중요할 수도 있기 때문에 한 state를 기준으로 하는게 아니라 출발 state를 기준으로 시차를 다 적어주어야함
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 0       TRAIN_000000                       NaN                     NaN
# 1       TRAIN_000001                     740.0                  1024.0
# 2       TRAIN_000002                    1610.0                  1805.0
# 3       TRAIN_000003                     905.0                  1735.0
# 4       TRAIN_000004                     900.0                  1019.0
# ...              ...                       ...                     ...
# 999990  TRAIN_999990                       NaN                   751.0
# 999991  TRAIN_999991                    1720.0                  1838.0
# 999992  TRAIN_999992                    1307.0                  1707.0
# 999993  TRAIN_999993                     603.0                   755.0
# 999999  TRAIN_999999                    1800.0                  2056.0
#
#           Origin_State Destination_State  Distance
# 0             Oklahoma             Texas     419.0
# 1             Illinois              Utah    1250.0
# 2       North Carolina          New York     544.0
# 3           California        New Jersey    2454.0
# 4           California        California     250.0
# ...                ...               ...       ...
# 999990        Illinois             Texas     802.0
# 999991        Virginia          New York     250.0
# 999992         Wyoming          Illinois    1162.0
# 999993        Virginia          Colorado    1452.0
# 999999         Florida          Michigan    1084.0
#
# [793902 rows x 6 columns]

# %%
origin_state_list = df['Origin_State'].unique().tolist()
origin_state_list

# %%
destination_state_list = df['Destination_State'].unique().tolist()
destination_state_list

# %%
origin_state_list.sort()
destination_state_list.sort()

# %%
origin_state_list == destination_state_list  #일치
# Out:
# True

# %%
df = df.dropna()
df
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 1       TRAIN_000001                     740.0                  1024.0
# 2       TRAIN_000002                    1610.0                  1805.0
# 3       TRAIN_000003                     905.0                  1735.0
# 4       TRAIN_000004                     900.0                  1019.0
# 6       TRAIN_000006                    1742.0                  1903.0
# ...              ...                       ...                     ...
# 999989  TRAIN_999989                    1717.0                  2019.0
# 999991  TRAIN_999991                    1720.0                  1838.0
# 999992  TRAIN_999992                    1307.0                  1707.0
# 999993  TRAIN_999993                     603.0                   755.0
# 999999  TRAIN_999999                    1800.0                  2056.0
#
#           Origin_State Destination_State  Distance
# 1             Illinois              Utah    1250.0
# 2       North Carolina          New York     544.0
# 3           California        New Jersey    2454.0
# 4           California        California     250.0
# 6           New Jersey     Massachusetts     200.0
# ...                ...               ...       ...
# 999989      New Jersey           Florida    1023.0
# 999991        Virginia          New York     250.0
# 999992         Wyoming          Illinois    1162.0
# 999993        Virginia          Colorado    1452.0
# 999999         Florida          Michigan    1084.0
#
# [630076 rows x 6 columns]

# %%
len(df)
# Out:
# 630076

# %%
li = origin_state_list
li
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Puerto Rico',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'U.S. Pacific Trust Territories and Possessions',
#  'U.S. Virgin Islands',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
a = df[df['Origin_State']=='Alabama']['Destination_State'].values.tolist()

# %%
a = list(set(a))
a
# Out:
# ['North Carolina',
#  'Virginia',
#  'Colorado',
#  'Illinois',
#  'New York',
#  'Maryland',
#  'Florida',
#  'Nevada',
#  'Pennsylvania',
#  'Michigan',
#  'Texas',
#  'Georgia']

# %%
for i in a:
    if df[df['Origin_State']==i]

# %%
df[(df['Origin_State']=='Virginia') & (df['Destination_State']=='Alabama')]  #이렇게 해서 평균 거리랑, 도착시간-출발시간 //  alabama 출발 virginia 도착 // 1시간 10분
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 3049    TRAIN_003049                     750.0                   908.0
# 6494    TRAIN_006494                     837.0                   945.0
# 12711   TRAIN_012711                    1420.0                  1527.0
# 16134   TRAIN_016134                     759.0                   908.0
# 19627   TRAIN_019627                    1705.0                  1808.0
# ...              ...                       ...                     ...
# 985137  TRAIN_985137                    1705.0                  1807.0
# 986352  TRAIN_986352                     815.0                   910.0
# 993629  TRAIN_993629                     758.0                   922.0
# 997056  TRAIN_997056                     758.0                   913.0
# 997863  TRAIN_997863                     759.0                   902.0
#
#        Origin_State Destination_State  Distance
# 3049       Virginia           Alabama     693.0
# 6494       Virginia           Alabama     653.0
# 12711      Virginia           Alabama     613.0
# 16134      Virginia           Alabama     693.0
# 19627      Virginia           Alabama     596.0
# ...             ...               ...       ...
# 985137     Virginia           Alabama     596.0
# 986352     Virginia           Alabama     596.0
# 993629     Virginia           Alabama     693.0
# 997056     Virginia           Alabama     693.0
# 997863     Virginia           Alabama     693.0
#
# [204 rows x 6 columns]

# %%
df[(df['Origin_State']=='Alabama') & (df['Destination_State']=='Virginia')]  #평균 거리랑 도착시간- 출발시간  ///  3시간   --> 시차 한시간 차이 맞네
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 110     TRAIN_000110                     940.0                  1247.0
# 2773    TRAIN_002773                    1057.0                  1355.0
# 4846    TRAIN_004846                    1111.0                  1359.0
# 15118   TRAIN_015118                     603.0                   906.0
# 18033   TRAIN_018033                    1112.0                  1418.0
# ...              ...                       ...                     ...
# 977535  TRAIN_977535                    1056.0                  1359.0
# 981121  TRAIN_981121                     901.0                  1159.0
# 989382  TRAIN_989382                     855.0                  1150.0
# 993554  TRAIN_993554                    1829.0                  2130.0
# 997464  TRAIN_997464                    1840.0                  2128.0
#
#        Origin_State Destination_State  Distance
# 110         Alabama          Virginia     693.0
# 2773        Alabama          Virginia     653.0
# 4846        Alabama          Virginia     613.0
# 15118       Alabama          Virginia     653.0
# 18033       Alabama          Virginia     653.0
# ...             ...               ...       ...
# 977535      Alabama          Virginia     653.0
# 981121      Alabama          Virginia     613.0
# 989382      Alabama          Virginia     596.0
# 993554      Alabama          Virginia     613.0
# 997464      Alabama          Virginia     596.0
#
# [206 rows x 6 columns]

# %%
#함수로 만들어서 최종 데이터프레임에 apply 하는 식으로?

# %% [markdown]
# # 시차 고려

# %%
df
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 0       TRAIN_000000                       NaN                     NaN
# 1       TRAIN_000001                     740.0                  1024.0
# 2       TRAIN_000002                    1610.0                  1805.0
# 3       TRAIN_000003                     905.0                  1735.0
# 4       TRAIN_000004                     900.0                  1019.0
# ...              ...                       ...                     ...
# 999990  TRAIN_999990                       NaN                   751.0
# 999991  TRAIN_999991                    1720.0                  1838.0
# 999992  TRAIN_999992                    1307.0                  1707.0
# 999993  TRAIN_999993                     603.0                   755.0
# 999999  TRAIN_999999                    1800.0                  2056.0
#
#           Origin_State Destination_State  Distance  Delay
# 0             Oklahoma             Texas     419.0    NaN
# 1             Illinois              Utah    1250.0    NaN
# 2       North Carolina          New York     544.0    NaN
# 3           California        New Jersey    2454.0    NaN
# 4           California        California     250.0    NaN
# ...                ...               ...       ...    ...
# 999990        Illinois             Texas     802.0    NaN
# 999991        Virginia          New York     250.0    NaN
# 999992         Wyoming          Illinois    1162.0    0.0
# 999993        Virginia          Colorado    1452.0    NaN
# 999999         Florida          Michigan    1084.0    NaN
#
# [793902 rows x 7 columns]

# %%
def find_time_lag(train_df, state):
    OA = train_df[train_df['Origin_State'] == state]
    predict_st = OA.Destination_State.unique().tolist()
    DA = train_df[train_df['Destination_State'] == state]
    time_delay_dict = {}
    for st in predict_st:
        st_oa = OA[OA['Destination_State'] == st]
        st_oa_diff = st_oa.Estimated_Arrival_Time.mean() - st_oa.Estimated_Departure_Time.mean()
        st_da = DA[DA['Origin_State'] == st]
        st_da_diff = st_da.Estimated_Arrival_Time.mean() - st_da.Estimated_Departure_Time.mean()
        time_delay = st_da_diff - st_oa_diff
        time_delay_dict[state, st] = -((time_delay/2)//60)*60
    
    return time_delay_dict

# %%
time_delay = dict()
for i in train_df['Origin_State'].unique().tolist():
    time_delay.update(find_time_lag(train_df, i))

# %%
time_delay = dict()
for i in train_df['Origin_State'].unique().tolist():
    time_delay.update(find_time_lag(train_df, i))
print(time_delay)
# Out:
# {('Oklahoma', 'Texas'): 0, ('Oklahoma', 'Colorado'): -2, ('Oklahoma', 'Georgia'): 1, ('Oklahoma', 'Illinois'): 0, ('Oklahoma', 'New Jersey'): 1, ('Oklahoma', 'California'): -3, ('Oklahoma', 'Virginia'): 1, ('Oklahoma', 'Florida'): 1, ('Oklahoma', 'Missouri'): 0, ('Oklahoma', 'Nevada'): -1, ('Oklahoma', 'North Carolina'): 2, ('Oklahoma', 'Minnesota'): 0, ('Oklahoma', 'Arizona'): -2, ('Oklahoma', 'Utah'): -2, ('Oklahoma', 'Maryland'): 1, ('Oklahoma', 'Michigan'): 1, ('Oklahoma', 'Pennsylvania'): 1, ('Oklahoma', 'Washington'): -3, ('Illinois', 'Utah'): -1, ('Illinois', 'Missouri'): 0, ('Illinois', 'Kentucky'): 0, ('Illinois', 'Tennessee'): 0, ('Illinois', 'Ohio'): 0, ('Illinois', 'Minnesota'): 0, ('Illinois', 'West Virginia'): 2, ('Illinois', 'Michigan'): 1, ('Illinois', 'Oklahoma'): 0, ('Illinois', 'Washington'): 0, ('Illinois', 'New York'): 1, ('Illinois', 'Texas'): 0, ('Illinois', 'California'): 0, ('Illinois', 'Indiana'): 1, ('Illinois', 'Illinois'): 0, ('Illinois', 'Pennsylvania'): 0, ('Illinois', 'North Carolina'): -1, ('Illinois', 'Virginia'): 1, ('Illinois', 'North Dakota'): 0, ('Illinois', 'Massachusetts'): 0, ('Illinois', 'Florida'): 1, ('Illinois', 'Nevada'): 0, ('Illinois', 'New Mexico'): -2, ('Illinois', 'South Dakota'): -1, ('Illinois', 'Maine'): 1, ('Illinois', 'Louisiana'): -1, ('Illinois', 'Georgia'): 1, ('Illinois', 'Wisconsin'): 0, ('Illinois', 'Rhode Island'): -2, ('Illinois', 'Nebraska'): 0, ('Illinois', 'Alabama'): 0, ('Illinois', 'Arkansas'): 0, ('Illinois', 'South Carolina'): -1, ('Illinois', 'Maryland'): -1, ('Illinois', 'Arizona'): -1, ('Illinois', 'Iowa'): 0, ('Illinois', 'Colorado'): -1, ('Illinois', 'Connecticut'): -2, ('Illinois', 'Idaho'): -1, ('Illinois', 'Kansas'): 0, ('Illinois', 'New Jersey'): -1, ('Illinois', 'Mississippi'): 0, ('Illinois', 'New Hampshire'): -5, ('Illinois', 'Alaska'): 15, ('Illinois', 'Vermont'): 1, ('Illinois', 'Oregon'): 1, ('Illinois', 'Montana'): -1, ('Illinois', 'Puerto Rico'): 0, ('Illinois', 'Wyoming'): -2, ('Illinois', 'Hawaii'): 13, ('Illinois', 'U.S. Virgin Islands'): 2, ('North Carolina', 'New York'): 0, ('North Carolina', 'Kentucky'): 0, ('North Carolina', 'Washington'): 0, ('North Carolina', 'North Carolina'): 0, ('North Carolina', 'Connecticut'): -2, ('North Carolina', 'Colorado'): -1, ('North Carolina', 'Arkansas'): -2, ('North Carolina', 'South Carolina'): 0, ('North Carolina', 'Maryland'): 0, ('North Carolina', 'Tennessee'): 0, ('North Carolina', 'Utah'): -3, ('North Carolina', 'Massachusetts'): -1, ('North Carolina', 'Michigan'): 0, ('North Carolina', 'New Jersey'): 0, ('North Carolina', 'Minnesota'): -2, ('North Carolina', 'Mississippi'): -2, ('North Carolina', 'Texas'): -1, ('North Carolina', 'Pennsylvania'): 0, ('North Carolina', 'Florida'): -1, ('North Carolina', 'Virginia'): 0, ('North Carolina', 'Georgia'): 0, ('North Carolina', 'Illinois'): 1, ('North Carolina', 'Alabama'): -2, ('North Carolina', 'Missouri'): -2, ('North Carolina', 'Maine'): 0, ('North Carolina', 'Ohio'): 0, ('North Carolina', 'Louisiana'): -1, ('North Carolina', 'West Virginia'): 0, ('North Carolina', 'Rhode Island'): -3, ('North Carolina', 'Iowa'): -2, ('North Carolina', 'Indiana'): -1, ('North Carolina', 'Arizona'): -2, ('North Carolina', 'California'): 2, ('North Carolina', 'New Hampshire'): -2, ('North Carolina', 'Puerto Rico'): 0, ('North Carolina', 'Nevada'): 1, ('North Carolina', 'Oklahoma'): -2, ('North Carolina', 'Wisconsin'): -2, ('North Carolina', 'Nebraska'): -1, ('North Carolina', 'Oregon'): 15, ('North Carolina', 'U.S. Virgin Islands'): 1, ('North Carolina', 'Vermont'): 0, ('North Carolina', 'South Dakota'): -4, ('California', 'New Jersey'): -1, ('California', 'California'): 0, ('California', 'Utah'): 1, ('California', 'Missouri'): 1, ('California', 'Nevada'): 0, ('California', 'Florida'): -2, ('California', 'Oregon'): -1, ('California', 'Arizona'): 0, ('California', 'Indiana'): 0, ('California', 'New Mexico'): 0, ('California', 'Hawaii'): 2, ('California', 'Texas'): 2,  ...

# %%
len(time_delay)
# Out:
# 1398

# %%
s = pd.DataFrame(time_delay, index=['time_delay']).T

# %%
def find_time_lag(train_df, state):
    OA = train_df[train_df['Origin_State'] == state]  #출발 state a
    predict_st = OA.Destination_State.unique().tolist() #출발 state a의 도착 state 리스트 //  destination_list와 동일 
    DA = train_df[train_df['Destination_State'] == state] #도착 state a
    time_delay_dict = {}
    for st in predict_st:
        st_oa = OA[OA['Destination_State'] == st] #출발a , 도착[1,2,3,4]  for문 
        st_oa_diff = st_oa.Estimated_Arrival_Time.mean() - st_oa.Estimated_Departure_Time.mean()
        st_da = DA[DA['Origin_State'] == st]
        st_da_diff = st_da.Estimated_Arrival_Time.mean() - st_da.Estimated_Departure_Time.mean()
        time_delay = st_da_diff - st_oa_diff
        if not np.isnan(time_delay):
            time_delay_dict[state, st] = -round(time_delay/2/60)
    
    return time_delay_dict

# %%
train_df.isna().sum()

# %%
test_df.isna().sum()

# %% [markdown]
# # 세번째

# %%
df
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 0       TRAIN_000000                       NaN                     NaN
# 1       TRAIN_000001                     740.0                  1024.0
# 2       TRAIN_000002                    1610.0                  1805.0
# 3       TRAIN_000003                     905.0                  1735.0
# 4       TRAIN_000004                     900.0                  1019.0
# ...              ...                       ...                     ...
# 999995  TRAIN_999995                     936.0                  1243.0
# 999996  TRAIN_999996                     920.0                  1028.0
# 999997  TRAIN_999997                     800.0                  1340.0
# 999998  TRAIN_999998                    1613.0                  1824.0
# 999999  TRAIN_999999                    1800.0                  2056.0
#
#           Origin_State Destination_State  Distance  Delay
# 0             Oklahoma             Texas     419.0    NaN
# 1             Illinois              Utah    1250.0    NaN
# 2       North Carolina          New York     544.0    NaN
# 3           California        New Jersey    2454.0    NaN
# 4           California        California     250.0    NaN
# ...                ...               ...       ...    ...
# 999995             NaN               NaN     678.0    NaN
# 999996             NaN         Minnesota     223.0    NaN
# 999997             NaN             Texas    1642.0    NaN
# 999998       Tennessee               NaN     214.0    NaN
# 999999         Florida          Michigan    1084.0    NaN
#
# [1000000 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# ID                               0
# Estimated_Departure_Time     86628
# Estimated_Arrival_Time       86516
# Origin_State                     0
# Destination_State                0
# Distance                         0
# Delay                       591429
# dtype: int64

# %%
df = df.dropna(subset=['Origin_State','Destination_State']) #결측치 제거

# %%
state_list = df['Origin_State'].unique().tolist()
state_list

# %%
list(set(df[df['Origin_State']=='Alabama']['Destination_State'].values.tolist())) #Alabama를 입력해주는 값에 따라 달라지기 ~
# Out:
# ['Illinois',
#  'North Carolina',
#  'Georgia',
#  'Florida',
#  'Texas',
#  'New York',
#  'Virginia',
#  'Nevada',
#  'Michigan',
#  'Pennsylvania',
#  'Maryland',
#  'Colorado']

# %%
#과정
# 1 . orinin_state == a / a는 전체 52개 state중 하나 
# 2. a에서 출발/ 도착한 state b -- b는 list(set(df[df['Origin_State']=='a']['Destination_State'].values.tolist())) 이 리스트에서 하나 
# 3 . 출발주 a / 도착주 b -- 여기서 도착시간 - 출발시간 의 평균 --  첫번째 시간 A_time  
# 4. 출발 b / 도착 a -- 여기서 도착시간- 출발시간의 평균 --  두번째 시간  B_time
# 5 . (A_time - B_time)/2

# %%
#1. origin_state ==a 
df[df['Origin_State']=='Alabama']

#2. a(Alabama)에서 출발하고 도착한 주 리스트로 정리
destination_list = list(set(df[df['Origin_State']=='Alabama']['Destination_State'].values.tolist()))

#3. 출발주a / 도착주 b-- 위에 정리한 리스트 중 하나 
for b in destination_list:
    df[(df['Origin_State']=='Alabama') & (df['Destination_State']==b)]

df[(df['Origin_State']=='Alabama') & (df['Destination_State']=='Illinois')]
df[(df['Origin_State']=='Illinois') & (df['Destination_State']=='Alabama')]

# %%
df[df['Origin_State']=='Alabama']

# %%
destination_list = list(set(df[df['Origin_State']=='Alabama']['Destination_State'].values.tolist()))
destination_list

# %%
a = df[(df['Origin_State']=='Alabama') & (df['Destination_State']=='Illinois')]
a_time = (a['Estimated_Arrival_Time']-a['Estimated_Departure_Time']).mean()  #1번

# %%
b = df[(df['Origin_State']=='Illinois') & (df['Destination_State']=='Alabama')]
b_time = (b['Estimated_Arrival_Time']-b['Estimated_Departure_Time']).mean()  #2번 
# b.isna().sum()

# %%
#최종 
# 1번 - 2번 /2 
(a_time - b_time)/2
# Out:
# 9.706989529712502

# %%
destination_list #state = ;Alibama
# Out:
# ['Illinois',
#  'North Carolina',
#  'Georgia',
#  'Florida',
#  'Texas',
#  'New York',
#  'Virginia',
#  'Nevada',
#  'Michigan',
#  'Pennsylvania',
#  'Maryland',
#  'Colorado']

# %%
def time_diff(state):
    destination_list =  list(set(df[df['Origin_State']==state]['Destination_State'].values.tolist()))
    for d in destination_list:
        a = df[(df['Origin_State']==state) & (df['Destination_State']==d)] #ali 출발 , texas 도착
        b = df[(df['Origin_State']==d) & (df['Destination_State']==state)] #texas 출. ali 도착
        a_time = (a['Estimated_Arrival_Time']-a['Estimated_Departure_Time']).mean()     
        b_time = (b['Estimated_Arrival_Time']-b['Estimated_Departure_Time']).mean()
        time_di = (a_time - b_time)/2 #a_state와 b_state 의 시차  --> 출발a 도착b or 출발b 도착a인 데이터에 시차 컬럼 넣어주기 
        
        #1)dict 형태로 출발지:도착지 = 시차  ---> ?
    return

# %%
#시차 까지 구했는데 이 시차를 데이터 프레임 안에 time_diff 컬럼에 새로 넣어야함
# for 문 한번 돌때ㅔ 마다 . state와 d (destination_list 원소 하나)의 시차를 구하게 되는데 이 시차를, 출발state도착d & 출발d도착state 인 데이터에 넣어야함

# %%
time_diff('Alabama')
# Out:
# 9.706989529712502

# %%
data = df.head()
data
# Out:
#              ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 0  TRAIN_000000                       NaN                     NaN
# 1  TRAIN_000001                     740.0                  1024.0
# 2  TRAIN_000002                    1610.0                  1805.0
# 3  TRAIN_000003                     905.0                  1735.0
# 4  TRAIN_000004                     900.0                  1019.0
#
#      Origin_State Destination_State  Distance  Delay
# 0        Oklahoma             Texas     419.0    NaN
# 1        Illinois              Utah    1250.0    NaN
# 2  North Carolina          New York     544.0    NaN
# 3      California        New Jersey    2454.0    NaN
# 4      California        California     250.0    NaN

# %%
data['diff_time'] = data.apply(lambda x : x['Estimation_Departure_Time'] )

# %%
#여기서 차이를 타임 diff로 넣는다고 하면
data['diff_time'].apply(lambda x : )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-5c822a987af2> in <cell line: 2>()
#       1 #여기서 차이를 타임 diff로 넣는다고 하면
# ----> 2 data[data['Origin_State']=='Oklahoma']['diff']= a
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3968             self._setitem_array(key, value)
#    3969         elif isinstance(value, DataFrame):
# -> 3970             self._set_item_frame_value(key, value)
#    3971         elif (
#    3972             is_list_like(value)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    4123
#    4124         if len(value.columns) != 1:
# -> 4125             raise ValueError(
#    4126                 "Cannot set a DataFrame with multiple columns to the single "
#    4127                 f"column {key}"
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column diff

# %%
#1 ) 비행시간 > 시차계산 > 시차를 계산한 비행시간 ex) 도착-출발=3시간, 시차 1시간, 비행시간 = 4시간 > 거리별 비행시간을 계산하여 결측치 채워넣기  /// 여기서 이상치 계산하기  
#2 )

# %%
df[(df['Origin_State']=='Virginia') & (df['Destination_State']=='Alabama')]  #이렇게 해서 평균 거리랑, 도착시간-출발시간 //  alabama 출발 virginia 도착 // 1시간 10분
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 3049    TRAIN_003049                     750.0                   908.0
# 6494    TRAIN_006494                     837.0                   945.0
# 12711   TRAIN_012711                    1420.0                  1527.0
# 16134   TRAIN_016134                     759.0                   908.0
# 19627   TRAIN_019627                    1705.0                  1808.0
# ...              ...                       ...                     ...
# 985137  TRAIN_985137                    1705.0                  1807.0
# 986352  TRAIN_986352                     815.0                   910.0
# 993629  TRAIN_993629                     758.0                   922.0
# 997056  TRAIN_997056                     758.0                   913.0
# 997863  TRAIN_997863                     759.0                   902.0
#
#        Origin_State Destination_State  Distance
# 3049       Virginia           Alabama     693.0
# 6494       Virginia           Alabama     653.0
# 12711      Virginia           Alabama     613.0
# 16134      Virginia           Alabama     693.0
# 19627      Virginia           Alabama     596.0
# ...             ...               ...       ...
# 985137     Virginia           Alabama     596.0
# 986352     Virginia           Alabama     596.0
# 993629     Virginia           Alabama     693.0
# 997056     Virginia           Alabama     693.0
# 997863     Virginia           Alabama     693.0
#
# [204 rows x 6 columns]

# %%
df[(df['Origin_State']=='Alabama') & (df['Destination_State']=='Virginia')]  #평균 거리랑 도착시간- 출발시간  ///  3시간   --> 시차 한시간 차이 맞네
# Out:
#                   ID  Estimated_Departure_Time  Estimated_Arrival_Time  \
# 110     TRAIN_000110                     940.0                  1247.0
# 2773    TRAIN_002773                    1057.0                  1355.0
# 4846    TRAIN_004846                    1111.0                  1359.0
# 15118   TRAIN_015118                     603.0                   906.0
# 18033   TRAIN_018033                    1112.0                  1418.0
# ...              ...                       ...                     ...
# 977535  TRAIN_977535                    1056.0                  1359.0
# 981121  TRAIN_981121                     901.0                  1159.0
# 989382  TRAIN_989382                     855.0                  1150.0
# 993554  TRAIN_993554                    1829.0                  2130.0
# 997464  TRAIN_997464                    1840.0                  2128.0
#
#        Origin_State Destination_State  Distance
# 110         Alabama          Virginia     693.0
# 2773        Alabama          Virginia     653.0
# 4846        Alabama          Virginia     613.0
# 15118       Alabama          Virginia     653.0
# 18033       Alabama          Virginia     653.0
# ...             ...               ...       ...
# 977535      Alabama          Virginia     653.0
# 981121      Alabama          Virginia     613.0
# 989382      Alabama          Virginia     596.0
# 993554      Alabama          Virginia     613.0
# 997464      Alabama          Virginia     596.0
#
# [206 rows x 6 columns]
